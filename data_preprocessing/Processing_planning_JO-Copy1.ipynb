# %% [markdown]
# # Parsing du document texte

# %%
import codecs

# Ouvrir le fichier en lecture seule
file = codecs.open('Planning_JO2024_v3.txt', "r", "utf-8")
# utiliser readlines pour lire toutes les lignes du fichier
# La variable "lignes" est une liste contenant toutes les lignes du fichier
lines = file.readlines()
# fermez le fichier après avoir lu les lignes
file.close()
words = []
for line in lines:
    print(line)
# Out:
# ATHLETISME
#
# Calendrier par épreuves
#
# Version  2
#
#
#
# JOUR	6		Jeudi	1	Août
#
# Session	 ATH01	 Début :	07:30 Fin :	11:05 Trocadéro
#
# Nom de l'épreuve/des épreuves
#
# 20 km marche - hommes, finale
#
# 20 km marche - femmes, finale
#
#
#
# JOUR	7		Vendredi	2	Août
#
# Session		ATH02	Début :	10:00	Fin :	13:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# Décathlon - 100 m, hommes
#
# Lancer de marteau - hommes, qualifications Saut en hauteur - femmes, qualifications 100 m - femmes, tour préliminaire Décathlon - saut en longueur, hommes
#
# 1 500 m - hommes, 1er tour 100 m - femmes, 1er tour
#
# Décathlon - lancer de poids, hommes
#
#
#
# Session	 ATH03	 Début :	17:40 Fin :	22:00 Stade de France
#
# Nom de l'épreuve/des épreuves Décathlon - saut en hauteur, hommes 5 000 m - femmes, 1er tour
#
# Triple saut - femmes, qualifications Lancer de disque - femmes, qualifications Relais 4 x 400 m - mixte, 1er tour
#
# 800 m - femmes, 1er tour
#
# Lancer de poids - hommes, qualifications Décathlon - 400 m, hommes
#
# 10 000 m - hommes, finale
#
#
#
# JOUR	8		Samedi	3	Août
#
# Session		ATH04	Début :	10:00	Fin :	16:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# Décathlon - 110 m haies, hommes
#
# Saut à la perche - hommes, qualifications 100 m - hommes, tour préliminaire
#
# Décathlon - lancer de disque, hommes 800 m - femmes, Repêchages
#
# 100 m - hommes, 1er tour
#
# Décathlon - saut à la perche, hommes
#
#
#
# Session	 ATH05	 Début :	19:00 Fin :	22:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# 1 500 m - hommes, Repêchages
#
#  Lancer de poids - hommes, finale	 100 m - femmes, demi-finales
#
# Décathlon - lancer de javelot, hommes
#
#  Décathlon - 1 500 m, hommes
#
#
#
# JOUR	9		Dimanch	4	Août
#
# Session		ATH06	Début :	10:00	Fin :	13:15 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# 3 000 m steeple - femmes, 1er tour
#
# Lancer de marteau - femmes, qualifications 200 m - femmes, 1er tour
#
# Saut en longueur - hommes, qualifications 110 m haies - hommes, 1er tour
#
# 400 m haies - femmes, 1er tour 110 m haies - hommes, 1er tour
#
#
#
# Session ATH07
#
#
#
# Début :	18:30 Fin :	22:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# 400 m - hommes, 1er tour
#
# 100 m - hommes, demi-finales
#
# 800 m - femmes, demi-finales
#
# 1 500 m - hommes, demi-finales
#
# Saut en hauteur - femmes, finale
#
# Lancer de marteau - hommes, finale
#
# 100 m - hommes, finale
#
#
#
# JOUR	10		Lundi	5	Août
#
# Session		ATH08	Début :	10:00	Fin :	13:15 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# 400 m haies - hommes, 1er tour
#
# Lancer de disque - hommes, qualifications Saut à la perche - femmes, qualifications 400 m haies - femmes, Repêchages
#
# 400 m - hommes, Repêchages 400 m - femmes, 1er tour
#
# 200 m - femmes, Repechages
#
#
#
#
#
# Session
#
#
#
# Début :	18:30 Fin :	22:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
#
#
#
#
#
#
# 3 000 m steeple - hommes, 1er tour 200 m - hommes, 1er tour
#
#
#
# 200 m - femmes, demi-finales
#
#
#
# JOUR	11		Mardi	6	Août
#
# Session		ATH10	Début :	10:00	Fin :	13:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# 1 500 m - femmes, 1er tour
#
# Lancer de javelot - hommes, qualifications 110 m haies - hommes, Repêchages Saut en longueur - femmes, qualifications 400 m - femmes, Repêchages
#
# 400 m haies - hommes, Repêchages 200 m - hommes, Repêchages
#
#
#
#
#
# Session
#
#
#
# Début :	19:00 Fin :	22:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# 400 m - hommes, demi-finales
#
#
#
#
#
#
#
# 400 m haies - femmes, demi-finales
#
#
#
# JOUR	12		Mercredi	7	Août
#
# Session		ATH12	Début :	07:30	Fin :	10:50 Trocadéro
#
# Nom de l'épreuve/des épreuves
#
#
#
#
#
# Session	ATH13
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Session
#
#
#
# Début :	10:00 Fin :	13:05 Stade de France
#
# Nom de l'épreuve/des épreuves
#
# Saut en hauteur - hommes, qualifications 100 m haies - femmes, 1er tour
#
# Lancer de javelot - femmes, qualifications 5 000 m - hommes, 1er tour
#
# 800 m - hommes, 1er tour 1 500 m - femmes, R
#
#
#
# Début :	18:30 Fin :	22:00 Stade de France
#
# Nom de l'épreuve/des épreuves
#
#
#
#
#
#
#
# 110 m haies - hommes, demi-finales Triple saut - hommes, qualifications 400 m haies - hommes, demi-finales 200 m - hommes, demi-finales
#
#
#
# 400 m - femmes, demi-finales
#
#
#
# 3 000 m steeple - hommes, finale
#
#
#
# JOUR	13		Jeudi	8	Août
#
# Session		ATH15	Début :	10:00	Fin :	13:00 Stade de France
#
# Nom de l'épreuve/des épreuves Heptathlon - 100 m haies, femmes Lancer de poids - femmes, qualifications 100 m haies - femmes, Repêchages Heptathlon - saut en hauteur, femmes Relais 4 x 100 m - femmes, 1er tour Relais 4 x 100 m - hommes, 1er tour 800 m - hommes, Repêchages
#
#
#
# Session	 ATH16	 Début :	19:00 Fin :	22:00 Stade de France
#
# Nom de l'épreuve/des épreuves Heptathlon - lancer de poids, femmes 1 500 m - femmes, demi-finales
#
#
#
# Heptathlon - 200 m, femmes
#
#
#
# JOUR	14		Vendredi	9	Août
#
# Session		ATH17	Début :	10:00	Fin :	13:15 Stade de France
#
# Nom de l'épreuve/des épreuves Heptathlon - saut en longueur, femmes Relais 4 x 400 m - femmes, 1er tour Relais 4 x 400 m - hommes, 1er tour Heptathlon - lancer de javelot, femmes 800 m - hommes, demi-finales
#
# 100 m haies - femmes, demi-finales
#
#
#
# Session	 ATH18	 Début :	19:00 Fin :	22:30 Stade de France
#
# Nom de l'épreuve/des épreuves
#
#
#
# JOUR	15		Samedi	10	Août
#
# Session		ATH19	Début :	08:00	Fin :	11:00 Hôtel de Ville (site de départ) - Invalides (site d'arrivée)
#
# Nom de l'épreuve/des épreuves
#
#  Marathon - hommes, finale
#
#
#
# Session	 ATH20	 Début :	18:30 Fin :	22:30 Stade de France
#
# Nom de l'épreuve/des épreuves
#
#
#
# Session	 ATH21	 Début :	08:00 Fin :	11:15 Hôtel de Ville (site de départ) - Invalides (site d'arrivée)
#
# Nom de l'épreuve/des épreuves
#
#  Marathon - femmes, finale
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# AVIRON
#
# Calendrier par épreuves
#
#
#
# Version :
#
#
#
#
#
# Session	ROW01
#
#
#
# 1
#
#
#
#
#
# Début :	09:00 Fin :	13:10	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves Skiff - hommes, éliminatoires Skiff - femmes, éliminatoires
#
# Deux de couple - hommes, éliminatoires Deux de couple - femmes, éliminatoires Quatre de couple - hommes, éliminatoires Quatre de couple - femmes, éliminatoires
#
#
#
#
#
# JOUR	2		Dim	28	Juillet
#
# Session		ROW02	Début :	09:00 Fin :	13:10	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Skiff - femmes, repêchages Skiff - hommes, repêchages
#
# Deux de couple - femmes, repêchage Deux de couple - hommes, repêchage
#
# Deux de pointe sans barreur - femmes, éliminatoires Deux de pointe sans barreur - hommes, éliminatoires Deux de couple poids léger - femmes, éliminatoires Deux de couple poids léger - hommes, éliminatoires Quatre de pointe sans barreur - femmes, éliminatoires Quatre de pointe sans barreur - hommes, éliminatoires
#
#
#
# JOUR	3		Lun	29	Juillet
#
# Session		ROW03	Début :	09:30 Fin :	12:20	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves Skiff - hommes, demi-finales E/F Skiff - femmes, demi-finales E/F
#
# Deux de pointe sans barreur - hommes, repêchage Deux de pointe sans barreur - femmes, repêchage Deux de couple poids léger - hommes, repêchages Deux de couple poids léger - femmes, repêchages Quatre de couple - hommes, repêchage
#
# Quatre de couple - femmes, repêchage
#
# Huit de pointe avec barreur - hommes, éliminatoires Huit de pointe avec barreur - femmes, éliminatoires
#
#
#
# JOUR	4		Mar	30	Juillet
#
# Session		ROW04	Début :	09:30 Fin :	11:50	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves Skiff - femmes, quarts de finale Skiff - hommes, quarts de finale
#
# Deux de couple - femmes, demi-finales
#
# Deux de couple - hommes, demi-finales
#
# Quatre de pointe sans barreur - femmes, repêchage Quatre de pointe sans barreur - hommes, repêchage
#
#
#
# JOUR	5	Mer	31	Juillet
#
# Session		 ROW05	 Début :	09:30 Fin :	13:10	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Deux de couple poids léger - femmes, finale C Deux de couple poids léger - hommes, finale C Skiff - hommes, demi-finales C/D
#
# Skiff - femmes, demi-finales C/D
#
# Deux de pointe sans barreur - hommes, demi-finales Deux de pointe sans barreur - femmes, demi-finales Deux de couple poids léger - hommes, demi-finales Deux de couple poids léger - femmes, demi-finales Quatre de couple - hommes, finale B
#
# Quatre de couple - femmes, finale B
#
#
#
# JOUR	6	Jeu	1	Août
#
# Session		 ROW06	 Début :	09:30 Fin :	12:40	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves Skiff - femmes, demi-finales A/B Skiff - hommes, demi-finales A/B
#
# Huit de pointe avec barreur - femmes, repêchage Huit de pointe avec barreur - hommes, repêchage Deux de couple - femmes, finale B
#
# Deux de couple - hommes, finale B
#
# Quatre de pointe sans barreur - femmes, finale B Quatre de pointe sans barreur - hommes, finale B
#
#
#
#
#
# JOUR	7	Ven	2	Août
#
# Session		 ROW07	 Début :	09:30 Fin :	12:50	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Skiff - hommes, finale F Skiff - femmes, finale F Skiff - hommes, finale E Skiff - femmes, finale E Skiff - hommes, finale D Skiff - femmes, finale D
#
# Deux de pointe sans barreur - hommes, finale B Deux de pointe sans barreur - femmes, finale B Deux de couple poids léger - hommes, finale B Deux de couple poids léger - femmes, finale B
#
#
#
#
#
#
#
#
#
#
#
# JOUR	8	Sam	3	Août
#
# Session		 ROW08	 Début :	09:30 Fin :	11:40	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Skiff - femmes, finale C Skiff - hommes, finale C Skiff - femmes, finale B Skiff - hommes, finale B
#
#
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# A noter que l'ordre des matchs sera déterminé pendant les Jeux en fonction du temps de repos des athlètes, des demandes des diffuseurs et d'autres paramètres qu'il n'est pas possible d'anticip
#
#
#
# BADMINTON
#
# Calendrier par épreuves Version :
#
# 1
#
# JOUR	1		Samedi	27	Juillet
#
#
#
# Session	BDM01
#
#
#
# Début :	08:30 Fin :	12:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Simple femmes, poules préliminaires Double hommes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
#
#
# Session	BDM02
#
#
#
# Début :	14:00 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Simple femmes, poules préliminaires Double hommes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
#
#
# Session	BDM03
#
#
#
# Début :	19:30 Fin :	23:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, poules préliminaires Double hommes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
# JOUR	2		Dimanch	28	Juillet
#
# Session		BDM04	Début :	08:30	Fin :	12:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Simple femmes, poules préliminaires Double hommes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
# Session	BDM05
#
#
#
# Début :	14:00 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Double femmes, poules préliminaires Double hommes, poules préliminaires Simple femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
#
#
# Session	BDM06
#
#
#
# Début :	19:30 Fin :	23:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Double hommes, poules préliminaires Simple femmes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
# JOUR	3		Lundi	29	Juillet
#
# Session		BDM07	Début :	08:30	Fin :	12:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Double hommes, poules préliminaires Simple femmes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
# Session	BDM08
#
#
#
# Début :	14:00 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Double femmes, poules préliminaires Double hommes, poules préliminaires Simple femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
#
#
# Session	BDM09
#
#
#
# Début :	19:30 Fin :	23:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double mixte, poules préliminaires Simple femmes, poules préliminaires Double hommes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
# JOUR	4		Mardi	30	Juillet
#
# Session		BDM10	Début :	08:30	Fin :	12:00	Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, poules préliminaires Double hommes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
# Session	BDM11
#
#
#
# Début :	14:00 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double hommes, poules préliminaires Double femmes, poules préliminaires Simple femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
#
#
# Session	BDM12
#
#
#
# Début :	19:30 Fin :	23:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, poules préliminaires Double hommes, poules préliminaires Double femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
# JOUR	5		Mercredi	31	Juillet
#
# Session		BDM13	Début :	08:30	Fin :	12:00	Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
# Session	BDM14
#
#
#
# Début :	14:00 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, poules préliminaires Simple hommes, poules préliminaires
#
#
#
#
#
#
#
# Session	BDM15
#
#
#
# Début :	19:30 Fin :	23:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, poules préliminaires Simple hommes, poules préliminaires Double mixte, quarts de finale
#
#
#
#
#
# JOUR	6		Jeudi	1	Août
#
# Session		BDM16	Début :	08:30	Fin :	11:00	Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double femmes, quarts de finale Simple hommes, 8e de finale
#
#
#
#
#
# Session	BDM17
#
#
#
# Début :	13:00 Fin :	16:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double hommes, quarts de finale Simple hommes, 8e de finale
#
#
#
#
#
#
#
# Session	BDM18
#
#
#
# Début :	18:30 Fin :	22:00 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, 8e de finale Double mixte, demi-finale
#
#
#
#
#
# JOUR	7		Vendredi	2	Août
#
# Session		BDM19	Début :	08:30	Fin :	13:00	Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Double femmes, demi-finale Double hommes, demi-finale
#
#
#
#
#
# Session
#
#
#
# Début :	15:00 Fin :	22:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves
#
# Double mixte, match bronze
#
#
#
#
#
#
#
# Simple hommes, quarts de finale
#
#
#
# JOUR	8		Samedi	3	Août
#
# Session		BDM21	Début :	08:30	Fin :	13:00	Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves
#
# Simple femmes, quarts de finale
#
#
#
#
#
# Session
#
#
#
# Début :	15:00 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves
#
# Double femmes, match bronze
#
#
#
#
#
#
#
#
#
# JOUR	9		Dimanch	4	Août
#
# Session		BDM23	Début :	08:30	Fin :	13:00	Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves Simple femmes, demi-finales Simple hommes, demi-finales
#
#
#
# Session	 BDM24	 Début :	15:00 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves
#
# Double hommes, match bronze
#
#
#
#  Double hommes, match or
#
#
#
# JOUR	10	Lundi	5	Août
#
# Session		 BDM25	 Début :	09:45	Fin :	12:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves
#
# Simple femmes, match bronze
#
#  Simple femmes, match or
#
#
#
# Session	 BDM26	 Début :	14:30 Fin :	17:30 Arena Porte de La Chapelle
#
# Nom de l'épreuve/des épreuves
#
# Simple hommes, match bronze
#
#  Simple hommes, match or
#
#
#
# *En attente de la décision finale
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# BASKETBALL
#
# Calendrier par épreuves
#
# 	Version :	1.1
#
# JOUR	1		Samedi	27	Juillet
#
# Session		BKB01	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB02	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB03	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire
#
#
#
#
#
# JOUR	2		Dimanch	28	J illet
#
# Session		BKB04	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB05	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB06	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire
#
#
#
#
#
# JOUR	3		L ndi	29	J illet
#
# Session		BKB07	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB08	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB09	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire
#
#
#
#
#
# JOUR	4		Mardi	30	Juillet
#
# Session		BKB10	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB11	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB12	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire
#
#
#
#
#
# JOUR	5		Mercredi	31	J illet
#
# Session		BKB13	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB14	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire
#
#
#
# Session
#
#
#
# BKB15	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire
#
#
#
#
#
# JOUR	6		Jeudi	1	Août
#
# Session		BKB16	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB17	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB18	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire
#
#
#
#
#
# JOUR	7		Vendredi	2	Août
#
# Session		BKB19	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB20	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB21	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire
#
#
#
#
#
# JOUR	8		Samedi	3	Août	Août
#
# Session		BKB22	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB23	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB24	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Hommes ou Femmes, tour préliminaire
#
#
#
#
#
# JOUR	9		Dimanch	4	Août
#
# Session		BKB25	Début :	11:00	Fin :	15:15	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session
#
#
#
# BKB26	Début :	17:15	Fin :	19:00	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire
#
#
#
#
#
#
#
# Session
#
#
#
# BKB27	Début :	21:00	Fin :	22:45	Stade Pierre Mauroy*
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire
#
#
#
#
#
#
#
# JOUR		Mard	6	Août
#
# Session	BKB28	Début:	11:00	Fin:	13:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Hommes, quart de finale
#
#
#
#
#
# Session	BKB29
#
#
#
#
#
#
#
# Session	BKB30
#
#
#
# Début:	14:30	Fin:	16:30	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Hommes, quart de finale
#
#
#
# Début:	18:00	Fin:	20:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
#
#
# Hommes, quart de finale
#
#
#
# Session	BKB31
#
#
#
# Début:	21:30	Fin:	23:30	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Hommes, quart de finale
#
#
#
#
#
# JOUR	12		Mercredi	7	Août
#
# Session		BKB32	Début:	11:00	Fin:	13:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Femmes, quart de finale
#
#
#
#
#
# Session	BKB33
#
#
#
#
#
#
#
# Session	BKB34
#
#
#
#
#
#
#
# Session	BKB35
#
#
#
# Début:	14:30	Fin:	16:30	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Femmes, quart de finale
#
#
#
# Début:	18:00	Fin:	20:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Femmes, quart de finale
#
#
#
# Début:	21:30	Fin:	23:30	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Femmes, quart de finale
#
#
#
#
#
# JOUR	13		Jeudi	8	Août
#
# Session		BKB36	Début:	17:30	Fin:	19:30	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Hommes, demi-finale
#
#
#
#
#
# Session	BKB37
#
#
#
# Début:	21:00	Fin:	23:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Hommes, demi-finale
#
#
#
#
#
# JOUR	14		Vendredi	9	Août
#
# Session		BKB38	Début:	17:30	Fin:	19:30	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Femmes, demi-finale
#
#
#
#
#
# Session	BKB39
#
#
#
# Début:	21:00	Fin:	23:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Femmes, demi-finale
#
#
#
#
#
# JOUR	15		Samedi	10	Août
#
# Session		BKB40	Début:	11:00	Fin:	13:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Hommes, match pour la médaille de bronze
#
#
#
# Session	 BKB41	 Début:	21:30	Fin:	00:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
#  Hommes, match pour la médaille d'or
#
#
#
# JOUR	16		Dimanch	11	Août
#
# Session		BKB42	Début:	11:30	Fin:	13:30	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
# Femmes, match pour la médaille de bronze
#
#
#
# Session	 BKB43	 Début:	15:30	Fin:	18:00	Arena Bercy
#
# Nom de l'épreuve/des épreuves
#
#  Femmes, match pour la médaille d'or
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
#
#
# BASKETBALL 3x3
#
# Calendrier par épreuves
#
# Version : 1
#
#
#
# JOUR	4		Mardi	30	Juillet
#
# Session		BK301	Début :	17:30 Fin :	19:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
# Session	BK302
#
#
#
# Début :	21:00 Fin :	23:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
# JOUR	5		Mercredi	31	Juillet
#
# Session		BK303	Début :	17:30 Fin :	19:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
# Session	BK304
#
#
#
# Début :	21:00 Fin :	23:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
# Jour	6		Jeudi	1	Août
#
# Session		BK305	Début :	09:00	Fin :	11:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
# Session	BK306
#
#
#
# Début :	12:30 Fin :	14:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
#
#
# Session	BK307
#
#
#
# Début :	18:00 Fin :	20:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
#
#
# Session	BK308
#
#
#
# Début :	21:30 Fin :	23:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
# Jour	7		Vendredi	2	Août
#
# Session		BK309	Début :	09:00	Fin :	11:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
# Session	BK310
#
#
#
# Début :	12:30 Fin :	14:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
#
#
# Session	BK311
#
#
#
# Début :	17:30 Fin :	19:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
#
#
# Session	BK312
#
#
#
# Début :	21:00 Fin :	23:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, matches de poule (2 matchs) Hommes, matches de poule (2 matchs)
#
#
#
#
#
# Jour	8		Samedi	3	Août
#
# Session		BK313	Début :	17:30	Fin :	19:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, matches de poule (4 matchs)
#
#
#
#
#
# Session	BK314
#
#
#
# Début :	21:30 Fin :	22:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, play in (2 matchs)
#
#
#
#
#
# Jour	9		Dimanche	4	Août
#
# Session		BK315	Début :	17:30	Fin :	19:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, matches de poule (4 matches)
#
#
#
#
#
# Session	BK316
#
#
#
# Début :	21:30 Fin :	22:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, play in (2 matchs)
#
#
#
#
#
# Jour	10		Lundi	5	Août
#
# Session		BK317	Début :	17:30	Fin :	19:30	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes et hommes, demi-finales
#
#
#
# Session	 BK318	 Début :	21:00 Fin :	23:20	La Concorde 1
#
# Nom de l'épreuve/des épreuves Femmes, match pour la médaille de bronze Hommes, match pour la médaille de bronze
#
#
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# BMX FREESTYLE
#
# Calendrier par épreuves
#
# 	Version :	1
#
# JOUR	4			Mardi	30	Juillet
#
# Session		BMF01		Début : 13:25	Fin :	16:30	La Concorde
#
# Nom de l'épreuve/des épreuves
#
# 				Park - femmes, qualification
#
# 				Park - hommes, qualification
#
# JOUR	5			Mercredi	31	Juillet
#
# Session		 BMF02		Début : 13:10	Fin :	16:30	La Concorde
#
# Nom de l'épreuve/des épreuves
#
# 				Park - femmes, finale
#
# 				Park - hommes, finale
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# BMX RACING
#
# Calendrier par épreuves
#
#
#
# Version :  1
#
#
#
#
#
# Session	BMX01
#
#
#
#
#
#
#
#
#
# Début :	20:00 Fin :	22:20	Stade BMX de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves Hommes, quarts de finale Femmes, quarts de finale
#
# Hommes, tour de la dernière chance
#
#
#
#
#
# Femmes, tour de la dernière chance
#
#
#
#
#
#
#
# JOUR	7		Vendredi	2	Août
#
# Session		 BMX02		Début :	20:00 Fin :	22:30	Stade BMX de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves
#
# Hommes, demi-finales Femmes, demi-finales
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# Breaking
#
# Calendrier par épreuves
#
#
#
# Version :	1
#
# Session	BKG01
#
#
#
#
#
#
#
#
#
# Début :	16:00	Fin :	18:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, qualifications
#
#
#
#
#
# Session	 BKG02	 Début :	20:00	Fin :	22:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
#  Femmes, finale
#
#
#
# JOUR	15		Samedi	10	Août
#
# Session		BKG03	Début :	16:00	Fin :	18:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, qualifications
#
#
#
# Session	 BKG04	 Début :	20:00	Fin :	22:00	La Concorde 1
#
# Nom de l'épreuve/des épreuves
#
#  Hommes, finale
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
#
#
# BOXE
#
# Calendrier par épreuves
#
#
#
# Version :
#
#
#
#
#
# Session	BOX01
#
#
#
# 2
#
#
#
#
#
# Début:	15:30 Fin:	17:55 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 54kg - Femmes, 1/32 finale combat 1 54kg - Femmes, 1/32 finale combat 2 54kg - Femmes, 1/32 finale combat 3 60kg - Femmes, 1/32 finale combat 1 60kg - Femmes, 1/32 finale combat 2 60kg - Femmes, 1/32 finale combat 3
#
# 63.5kg - Hommes, 1/32 finale combat 1
#
# 63.5kg - Hommes, 1/32 finale combat 2 80kg - Hommes, 1/32 finale combat 1
#
#
#
#
#
#
#
# Session	BOX02
#
#
#
# Début:	20:00 Fin:	22:25 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 54kg - Femmes, 1/32 finale combat 4 54kg - Femmes, 1/32 finale combat 5 54kg - Femmes, 1/32 finale combat 6 60kg - Femmes, 1/32 finale combat 4 60kg - Femmes, 1/32 finale combat 5 60kg - Femmes, 1/32 finale combat 6
#
# 63.5kg - Hommes, 1/32 finale combat 3
#
# 63.5kg - Hommes, 1/32 finale combat 4 80kg - Hommes, 1/32 finale combat 2
#
#
#
#
#
# JOUR	2		Dimanch	28	Juillet
#
# Session		BOX03	Début:	11:00	Fin:	13:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 57kg - Hommes, 1/32 finale combat 1 71kg - Hommes, 1/32 finale, combat 1 71kg - Hommes, 1/32 finale, combat 2 92kg - Hommes, 1/16 finale, combat 1 92kg - Hommes, 1/16 finale, combat 2 50kg - Femmes, 1/32 finale combat 1 50kg - Femmes, 1/32 finale combat 2 66kg - Femmes, 1/32 finale combat 3
#
#
#
#
#
# Session	BOX04
#
#
#
# Début:	15:30 Fin:	17:40 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 57kg - Hommes, 1/32 finale combat 2 71kg - Hommes, 1/32 finale, combat 3 92kg - Hommes, 1/16 finale, combat 3 92kg - Hommes, 1/16 finale, combat 4 92kg - Hommes, 1/16 finale, combat 4 50kg - Femmes, 1/32 finale combat 3 50kg - Femmes, 1/32 finale combat 4 66kg - Femmes, 1/32 finale combat 2
#
#
#
#
#
#
#
# Session	BOX05
#
#
#
# Début:	20:00 Fin:	22:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 71kg - Hommes, 1/32 finale combat 4 92kg - Hommes, 1/16 finale, combat 6 92kg - Hommes, 1/16 finale, combat 7 92kg - Hommes, 1/16 finale, combat 8 50kg - Femmes, 1/32 finale combat 5 50kg - Femmes, 1/32 finale combat 6 66kg - Femmes, 1/32 finale combat 3 66kg - Femmes, 1/32 finale combat 4
#
#
#
#
#
# JOUR	3		Lundi	29	Juillet
#
# Session		BOX06	Début:	11:00	Fin:	13:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 60kg - Femmes, 1/16 finale combat 7 60kg - Femmes, 1/16 finale combat 8 60kg - Femmes, 1/16 finale combat 9 63,5kg - Hommes, 1/16 finale combat 5 63,5kg - Hommes, 1/16 finale combat 6 63,5kg - Hommes, 1/16 finale combat 7
#
# +92kg - Hommes, 1/16 finale combat 1
#
# +92kg - Hommes, 1/16 finale combat 2
#
#
#
# Session	BOX07
#
#
#
# Début:	15:30 Fin:	17:40 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 60kg - Femmes, 1/16 finale combat 10 60kg - Femmes, 1/16 finale combat 11 63,5kg - Hommes, 1/16 finale combat 8 63,5kg - Hommes, 1/16 finale combat 9
#
# 63,5kg - Hommes, 1/16 finale combat 10
#
# +92kg - Hommes, 1/16 finale combat 3
#
# +92kg - Hommes, 1/16 finale combat 4
#
# +92kg - Hommes, 1/16 finale combat 5
#
#
#
#
#
#
#
# Session	BOX08
#
#
#
# Début:	20:00 Fin:	22:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 60kg - Femmes, 1/16 finale combat 12 60kg - Femmes, 1/16 finale combat 13 60kg - Femmes, 1/16 finale combat 14
#
# 63,5kg - Hommes, 1/16 finale combat 11 63,5kg - Hommes, 1/16 finale combat 12
#
# +92kg - Hommes, 1/16 finale combat 6
#
# +92kg - Hommes, 1/16 finale combat 7
#
# +92kg - Hommes, 1/16 finale combat 8
#
#
#
#
#
# JOUR	4		Mardi	30	Juillet
#
# Session		BOX09	Début:	11:00	Fin:	13:40 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 51kg - Hommes, 1/16 finale combat 1 51kg - Hommes, 1/16 finale combat 2 51kg - Hommes, 1/16 finale combat 3 80kg - Hommes, 1/16 finale combat 3 80kg - Hommes, 1/16 finale combat 4 54kg - Femmes, 1/16 finale combat 7 54kg - Femmes, 1/16 finale combat 8 54kg - Femmes, 1/16 finale combat 9 57kg - Femmes, 1/32 finale combat 1 57kg - Femmes, 1/32 finale combat 2
#
#
#
#
#
# Session	BOX10
#
#
#
# Début:	15:30 Fin:	18:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 51kg - Hommes, 1/16 finale combat 4 51kg - Hommes, 1/16 finale combat 5 51kg - Hommes, 1/16 finale combat 6 80kg - Hommes, 1/16 finale combat 5 80kg - Hommes, 1/16 finale combat 6 54kg - Femmes, 1/16 finale combat 10 54kg - Femmes, 1/16 finale combat 11 54kg - Femmes, 1/16 finale combat 12 57kg - Femmes, 1/32 finale combat 3 57kg - Femmes, 1/32 finale combat 4
#
#
#
#
#
#
#
# Session	BOX11
#
#
#
# Début:	20:00 Fin:	22:40 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 51kg - Hommes, 1/16 finale combat 7 51kg - Hommes, 1/16 finale combat 8 80kg - Hommes, 1/16 finale combat 7 80kg - Hommes, 1/16 finale combat 8 80kg - Hommes, 1/16 finale combat 9 80kg - Hommes, 1/16 finale combat 10 54kg - Femmes, 1/16 finale combat 13 54kg - Femmes, 1/32 finale combat 5 54kg - Femmes, 1/32 finale combat 6
#
#
#
#
#
# JOUR	5		Mercredi	31	Juillet
#
# Session		BOX12	Début:	11:00	Fin:	13:25 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 57kg - Hommes, 1/16 finale combat 3 57kg - Hommes, 1/16 finale combat 4 71kg - Hommes, 1/16 finale combat 5 71kg - Hommes, 1/16 finale combat 6 75kg - Femmes, 1/16 finale combat 1 75kg - Femmes, 1/16 finale combat 2 75kg - Femmes, 1/16 finale combat 3 75kg - Femmes, 1/16 finale combat 4
#
# 60kg - Femmes, quart de finale combat 15
#
#
#
# Session	BOX13
#
#
#
# Début:	15:30 Fin:	18:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 57kg - Hommes, 1/16 finale combat 5 57kg - Hommes, 1/16 finale combat 6 57kg - Hommes, 1/16 finale combat 7 71kg - Hommes, 1/16 finale combat 7 71kg - Hommes, 1/16 finale combat 8 71kg - Hommes, 1/16 finale combat 9 75kg - Femmes, 1/16 finale combat 5 75kg - Femmes, 1/16 finale combat 6
#
# 60kg - Femmes, quart de finale combat 16 60kg - Femmes, quart de finale combat 17
#
#
#
#
#
#
#
# Session	BOX14
#
#
#
# Début:	20:00 Fin:	22:25 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 57kg - Hommes, 1/16 finale combat 8 57kg - Hommes, 1/16 finale combat 9 57kg - Hommes, 1/16 finale combat 10 71kg - Hommes, 1/16 finale combat 10 71kg - Hommes, 1/16 finale combat 11 71kg - Hommes, 1/16 finale combat 12 75kg - Femmes, 1/16 finale combat 9 75kg - Femmes, 1/16 finale combat 10
#
# 60kg - Hommes quart de finale combat 18
#
#
#
#
#
# JOUR	6		Jeudi	1	Août
#
# Session		BOX15	Début:	11:00	Fin:	13:25 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 50kg - Femmes, 1/16 finale combat 7 50kg - Femmes, 1/16 finale combat 8 50kg - Femmes, 1/16 finale combat 9 66kg - Femmes, 1/16 finale combat 5 66kg - Femmes, 1/16 finale combat 6 66kg - Femmes, 1/16 finale combat 7
#
# 54kg - Femmes, quart de finale combat 15 63,5kg - Hommes quart de finale combat 13 92kg - Hommes quart de finale combat 9
#
#
#
#
#
# Session	BOX16
#
#
#
# Début:	15:30 Fin:	18:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 50kg - Femmes, 1/16 finale combat 10 50kg - Femmes, 1/16 finale combat 11 50kg - Femmes, 1/16 finale combat 12 66kg - Femmes, 1/16 finale combat 8 66kg - Femmes, 1/16 finale combat 9 66kg - Femmes, 1/16 finale combat 10
#
# 54kg - Femmes, quart de finale combat 16 54kg - Femmes, quart de finale combat 17 92kg - Hommes quart de finale combat 11 63,5kg - Hommes quart de finale combat 14 92kg - Hommes quart de finale combat 10
#
#
#
#
#
#
#
# Session	BOX17
#
#
#
# Début:	20:00 Fin:	22:25 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 50kg - Femmes, 1/16 finale combat 13 50kg - Femmes, 1/16 finale combat 14 66kg - Femmes, 1/16 finale combat 11 66kg - Femmes, 1/16 finale combat 12
#
# 54kg - Femmes, quart de finale combat 18
#
# 63,5kg - Hommes quart de finale combat 15 63,5kg - Hommes quart de finale combat 16 92kg - Hommes quart de finale combat 11 92kg - Hommes quart de finale combat 12
#
#
#
#
#
# JOUR	7		Vendredi	2	Août
#
# Session		BOX18	Début:	15:30	Fin:	18:10 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 57kg - Femmes, 1/16 finale combat 7 57kg - Femmes, 1/16 finale combat 8 57kg - Femmes, 1/16 finale combat 9 57kg - Femmes, 1/16 finale combat 10
#
# 51kg - Hommes quart de finale combat 9 51kg - Hommes quart de finale combat 10 80kg - Hommes quart de finale combat 11 80kg - Hommes quart de finale combat 12
#
# +92 kg- Hommes, quart de finale combat 9
#
# +92 kg- Hommes, quart de finale combat 10
#
#
#
# Session	BOX19
#
#
#
# Début:	20:00 Fin:	22:40 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves 57kg - Femmes, 1/16 finale combat 11 57kg - Femmes, 1/16 finale combat 12 57kg - Femmes, 1/16 finale combat 13 57kg - Femmes, 1/16 finale combat 14
#
# 51kg - Hommes quart de finale combat 11 51kg - Hommes quart de finale combat 12 80kg - Hommes quart de finale combat 13 80kg - Hommes quart de finale combat 14
#
# +92 kg- Hommes, quart de finale combat 11
#
# +92 kg- Hommes, quart de finale combat 12
#
#
#
#
#
# JOUR	8		Samedi	3	Août
#
# Session		BOX20	Début:	15:30	Fin:	17:55 Arena Paris Nord
#
#
#
# Time
#
#
#
# Total
#
#
#
# Nom de l'épreuve/des épreuves
#
# 57kg - Hommes, quart de finale, combat 11 57kg - Hommes, quart de finale, combat 12 71kg - Hommes, quart de finale, combat 13 71kg - Hommes, quart de finale, combat 14 50kg - Femmes, quart de finale, combat 15 50kg - Femmes, quart de finale, combat 16 66kg - femmes, quart de finale, combat 13 66kg - femmes, quart de finale, combat 14 60kg - femmes, demi-finale, combat 19
#
#
#
#
#
#
#
# Session	BOX21
#
#
#
# Début:	20:00 Fin:	22:25 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves
#
# 57kg - Hommes, quart de finale, combat 13 57kg - Hommes, quart de finale, combat 14 71kg - Hommes, quart de finale, combat 15
#
# 71kg - Hommes, quart de finale, combat 16 50kg - Femmes, quart de finale, combat 17 50kg - Femmes, quart de finale, combat 18
#
# 66kg - femmes, quart de finale, combat 15 66kg - femmes, quart de finale, combat 16 60kg - femmes, demi-finale, combat 20
#
#
#
#
#
# JOUR	9		Dimanch	4	Août
#
# Session		BOX22	Début:	11:00	Fin:	13:25 Arena Paris Nord
#
#
#
# Time
#
#
#
# Total
#
#
#
# Nom de l'épreuve/des épreuves
#
# 57kg - femmes, quart de finale combat 15 57kg - femmes, quart de finale combat 16 75kg - femmes, quart de finale combat 9 75kg - femmes, quart de finale combat 10 54kg - femmes, demi-finale combat 19
#
# 51kg - hommes, demi-finale combat 13 63,5kg - hommes, demi-finale combat 17 80kg - hommes, demi-finale combat 15 92kg - hommes, demi-finale combat 13
#
#
#
#
#
#
#
# Session	BOX23
#
#
#
# Début:	15:30 Fin:	17:55 Arena Paris Nord
#
# Nom de l'épreuve/des épreuves
#
# 57kg - femmes, quart de finale combat 17 57kg - femmes, quart de finale combat 18 75kg - femmes, quart de finale combat 11
#
# 75kg - femmes, quart de finale combat 12 54kg - femmes, demi-finale combat 20
#
# 51kg - hommes, demi-finale combat 14 63,5kg - hommes, demi-finale combat 18 80kg - hommes, demi-finale combat 16 92kg - hommes, demi-finale combat 14
#
#
#
#
#
# JOUR	11		Mardi	6	Août
#
# Session		Box 24	Début:	21:30	Fin:	23:30 Stade Roland-Garros - P.Chatrier
#
# Nom de l'épreuve/des épreuves
#
# 71kg - Hommes, demi-finale, combat 17 71kg - Hommes, demi-finale, combat 18 50 kg - Femmes, demi-finale, combat 19 50 kg - Femmes, demi-finale, combat 20 66 kg - Femmes, demi-finale, combat 17 66 kg - Femmes, demi-finale, combat 18
#
#
#
# 60kg - Femmes, cérémonie
#
#
#
#
#
# JOUR	12	Mercredi	7	Août
#
# Session		 BOX25	 Début:	21:30	Fin:	23:30 Stade Roland-Garros - P.Chatrier
#
# Nom de l'épreuve/des épreuves 57kg - femmes, demi-finale combat 19 57kg - femmes, demi-finale combat 20
#
# +92kg - hommes, demi-finale combat 13
#
# +92kg - hommes, demi-finale combat 14
#
# 63,5kg - hommes, cérémonie 80kg - hommes, cérémonie
#
#
#
# JOUR	13	Jeudi	8	Août
#
# Session		 BOX26	 Début:	21:30	Fin:	23:30 Stade Roland-Garros - P.Chatrier
#
# Nom de l'épreuve/des épreuves 57kg - hommes, demi-finale combat 15 57kg - hommes, demi-finale combat 16 75kg - femmes, demi-finale combat 13 75kg - femmes, demi-finale combat 14
#
#
#
#
#
#
#
#
#
# JOUR	14	Vendredi	9	Août
#
# Session		 BOX27	 Début:	21:30	Fin:	23:30 Stade Roland-Garros - P.Chatrier
#
# Nom de l'épreuve/des épreuves
#
# 71kg - hommes, cérémonie
#
#  92kg - hommes, finale combat 15	 50kg - femmes, cérémonie
#
#  66kg - femmes, finale combat 19	 92kg - hommes, cérémonie
#
# 66kg - femmes, cérémonie
#
#
#
# Session	 BOX28	 Début:	21:30 Fin:	23:30 Stade Roland-Garros - P.Chatrier
#
# Nom de l'épreuve/des épreuves
#
# 57kg - femmes, cérémonie
#
#  75kg - femmes, finale combat 15	 57kg - hommes, cérémonie
#
#  +92kg - hommes, finale combat 15	 75kg - femmes, cérémonie
#
# +92kg - femmes, cérémonie
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# CANOE SLALOM
#
# Calendrier par épreuves
#
#
#
# Version :	2
#
#
#
#
#
# Session	CSL01
#
#
#
#
#
#
#
#
#
# Début :	15:00 Fin :	19:10	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves
#
# Canoë - hommes, éliminatoires - manches 1 et 2 Kayak - femmes, éliminatoires - manches 1 et 2
#
#
#
#
#
# JOUR	2		Dimanche	28	Juillet
#
# Session	CSL02	Début :	15:30 Fin :	18:50	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves
#
# Kayak - femmes, demi-finale
#
#  Kayak - femmes, finale
#
#
#
# JOUR	3	Lundi	29	Juillet
#
# Session	 CSL03	 Début :	15:30 Fin :	18:30	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves
#
# Canoë - hommes, demi-finale
#
#  Canoë - hommes, finale
#
#
#
# JOUR	4		Mardi	30	Juillet
#
# Session	CSL04	Début :	15:00 Fin :	19:10	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves
#
# Canoë - femmes, éliminatoires - manches 1 et 2 Kayak - hommes, éliminatoires - manches 1 et 2
#
#
#
# JOUR	5	Mercredi	31	Juillet
#
# Session	 CSL05	 Début :	15:30 Fin :	18:30	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves
#
# Canoë - femmes, demi-finale
#
#  Canoë - femmes, finale
#
#
#
# JOUR	6	Jeudi	1	Août
#
# Session	 CSL06	 Début :	15:30 Fin :	18:35	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves
#
# Kayak - hommes, demi-finale
#
#  Kayak - hommes, finale
#
#
#
# JOUR	8		Samedi	3	Août
#
# Session	CSL07	Début :	15:30 Fin :	19:15	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves
#
# Kayak Cross - femmes, contre-la-montre Kayak Cross - hommes, contre-la-montre Kayak Cross - femmes, Repêchage 1 Kayak Cross - hommes, Repêchage 1 Kayak Cross - femmes, Repêchage 2 Kayak Cross - hommes, Repêchage 2
#
#
#
# JOUR	9		Dimanche	4	Août
#
# Session	CSL08	Début :	15:30 Fin :	17:25	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves Kayak Cross - hommes, Eliminatoires Kayak Cross - femmes, Eliminatoires
#
#
#
# JOUR	10	Lundi	5	Août
#
# Session	 CSL09	 Début :	15:30 Fin :	17:30	Stade nautique de Vaires-sur-Marne - Bassin eaux vives
#
# Nom de l'épreuve/des épreuves Kayak Cross - femmes, quarts de finale Kayak Cross - hommes, quarts de finale Kayak Cross - femmes, demi-finales
#
# Kayak Cross - hommes, demi-finales Kayak Cross - femmes, petite finale Kayak Cross - hommes, petite finale
#
#
#
#
#
#
#
#
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# CANOË, COURSE EN LIGNE
#
# Calendrier par épreuves
#
# Version :	1.1
#
#
#
# JOUR	11		Mardi	6	Août
#
# Session		CSP01	Début:	09:30	Fin:	14:50	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Kayak à quatre (K4) 500 m - femmes, éliminatoires Kayak à quatre (K4) 500 m - hommes, éliminatoires Canoë biplace (C2) 500 m - hommes, éliminatoires Canoë biplace (C2) 500 m - femmes, éliminatoires Kayak biplace (K2) 500 m - femmes, éliminatoires Kayak biplace (K2) 500 m - hommes, éliminatoires Canoë biplace (C2) 500 m - hommes, quarts de finale Canoë biplace (C2) 500 m - femmes, quarts de finale Kayak biplace (K2) 500 m - femmes, quarts de finale Kayak biplace (K2) 500 m - hommes, quarts de finale
#
#
#
# JOUR	12		Mercredi	7	Août
#
# Session		CSP02	Début:	09:30	Fin:	15:10	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Kayak monoplace (K1) 500 m - femmes, éliminatoires Kayak monoplace (K1) 1 000 m - hommes, éliminatoires Canoë monoplace (C1) 1 000 m - hommes, éliminatoires Kayak monoplace (K1) 500m - femmes, quarts de finale Kayak monoplace (K1) 1 000 m - hommes, quarts de finale Canoë monoplace (C1) 1 000 m - hommes, quarts de finale
#
#
#
# JOUR	13	Jeudi	8	Août
#
# Session		 CSP03	 Début:	10:30	Fin:	14:30	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Canoë monoplace (C1) 200 m - femmes, éliminatoires Canoë biplace (C2) 500 m - hommes, demi-finales Kayak à quatre (K4) 500 m - femmes, demi-finales Kayak à quatre (K4) 500 m - hommes, demi-finales
#
# Canoë monoplace (C1) 200 m - femmes, quarts de finale Canoë biplace (C2) 500 m - hommes, finale B
#
#
#
#
#
#
#
# JOUR	14	Vendredi	9	Août
#
# Session		 CSP04	 Début:	10:30	Fin:	14:40	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Canoë biplace (C2) 500 m - femmes, demi-finales Kayak biplace (K2) 500 m - femmes, demi-finales Kayak biplace (K2) 500 m - hommes, demi-finales
#
# Canoë monoplace (C1) 1 000 m - hommes, demi-finales Canoë biplace (C2) 500 m - femmes, finale B
#
#
#
# Kayak biplace (K2) 500 m - femmes, finale B
#
# Kayak biplace (K2) 500 m - hommes, finale B
#
#
#
# Canoë monoplace (C1) 1 000 m - hommes,finale B
#
#
#
# JOUR	15	Samedi	10	Août
#
# Session		 CSP05	 Début:	10:30	Fin:	14:20	Stade nautique de Vaires-sur-Marne - Bassin eaux calmes
#
# Nom de l'épreuve/des épreuves
#
# Kayak monoplace (K1) 500 m - femmes, demi-finales Kayak monoplace (K1) 1 000 m - hommes, demi-finales Canoë monoplace (C1) 200 m - femmes, demi-finales Kayak monoplace (K1) 500 m - femmes, finale C
#
# Kayak monoplace (K1) 500 m - femmes, finale B
#
# Kayak monoplace (K1) 1 000 m - hommes, finale B
#
#
#
# Canoë monoplace (C1) 200 m - femmes, finale B
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #C1-INTERNAL
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# CYCLISME SUR PISTE
#
# Calendrier par épreuves
#
# Version :	1
#
#
#
#
#
#
#
# Session
#
#
#
# Début :	17:00 Fin :	20:20	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves
#
# Vitesse par équipes - femmes, qualifications Poursuite équipes - hommes, qualifications Vitesse par équipes - femmes, 1er tour Vitesse par équipes - hommes, qualifications
#
#  Vitesse par équipes - femmes, finales
#
#
#
#
#
# JOUR	11	Mardi	6	Août
#
# Session		 CTR02	 Début :	17:30 Fin :	20:30	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves
#
# Poursuite par équipes - femmes, qualifications Vitesse par équipes - hommes, 1er tour Poursuite par équipes - hommes, 1er tour
#
#  Vitesse par équipes - hommes, finales
#
#
#
# JOUR	12		Mercredi	7	Août
#
# Session		CTR03	Début :	12:45 Fin :	15:45	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves Vitesse - hommes, qualifications Keirin - femmes, 1er tour
#
# Poursuite par équipes - femmes, 1er tour Vitesse - hommes, 32e finale
#
# Keirin - femmes, repêchages
#
# Vitesse - hommes, 32e finale - repêchages
#
#
#
# Session	 CTR04	 Début :	17:30 Fin :	20:25	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves
#
# Vitesse - hommes, 16e finale
#
#  Poursuite par équipes - hommes, finales
#
# Vitesse - hommes, 16e finale - repêchages
#
#  Poursuite par équipes - femmes, finales
#
# Vitesse - hommes, 8e finale
# Vitesse - hommes, 8e finale - repêchages
#
#
#
# JOUR	13	Jeudi	8	Août
#
# Session		 CTR05	 Début :	17:00 Fin :	20:25	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves Omnium - hommes, scratch 1/4 Keirin - femmes, 1/4 finale
#
# Omnium - hommes, course tempo 2/4 Vitesse - hommes, 1/4 finale
#
# Keirin - femmes, 1/2 finales
#
# Omnium - hommes, course à l'élimination Keirin - femmes, finale 7-12
#
#
#
# Vitesse - hommes, places 5-8
#
#
#
# JOUR	14		Vendredi	9	Août
#
# Session		CTR06	Début :	14:00 Fin :	16:00	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves Vitesse - femmes, qualifications Vitesse - hommes, 1/2 finales Vitesse - femmes, 32e finale
#
# Vitesse - femmes, 32e finale - repêchages
#
#
#
# Session	 CTR07	 Début :	18:00 Fin :	20:15	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves
#
# Madison - femmes, finale
#
# Vitesse - femmes, 16e finale
#
# Vitesse - hommes, finales
#
# Vitesse - femmes, 16e finale - repêchages
#
#
#
# JOUR	15	Samedi	10	Août
#
# Session		 CTR08	 Début :	17:00 Fin :	20:20	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves
#
# Vitesse - femmes, 8e finale Keirin - hommes, 1er tour
#
# Vitesse - femmes, 8e finale - repêchages
#
#  Madison - hommes, finale
#
# Vitesse - femmes, 1/4 finale Keirin - hommes, repêchages
#
#
#
# JOUR	16	Dimanche	11	Août
#
# Session		 CTR09	 Début :	11:00 Fin :	14:40	Vélodrome National de Saint-Quentin-en-Yvelines
#
# Nom de l'épreuve/des épreuves Omnium - femmes, scratch 1/4 Vitesse - femmes, 1/2 finales Keirin - hommes, 1/4 finale
#
# Omnium - femmes, course tempo 2/4 Vitesse - femmes, places 5-8
#
# Keirin - hommes, 1/2 finales
#
# Omnium - femmes, course à l'élimination Keirin - hommes, finale 7-12
#
#
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# CYCLISME SUR ROUTE
#
# Calendrier par épreuves
#
# Version :	1
#
#
#
# Session	 CRD01	 Début :	14:30 Fin :	18:30	Départ Invalides - Arrivée Pont Alexandre III
#
# Nom de l'épreuve/des épreuves
#
#
#
# JOUR	8	Samedi	3	Août
#
# Session		 CRD02	 Début :	11:00 Fin :	18:15	Trocadéro
#
# 		Nom de l'épreuve/des épreuves
#
# 		 Course en ligne - hommes
#
# JOUR	9	Dimanche	4	Août
#
# Session		 CRD03	 Début :	14:00 Fin :	18:45	Trocadéro
#
# Nom de l'épreuve/des épreuves
#
#  Course en ligne - femmes
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# Escalade
#
# Calendrier par épreuves
#
#
#
# Version :	1
#
#
#
#
#
# Session	CLB01
#
#
#
#
#
#
#
#
#
# Début :	10:00 Fin :	14:00	Site d'escalade du Bourget
# ...
#
#
#
#
#
# JOUR	8		Samedi	3	Août
#
# Session		VBV22	Début :	09:00	Fin :	13:00	Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Tour préliminaire - Femmes et hommes (4 matchs)
#
#
#
#
#
# Session	VBV23
#
#
#
# Début :	16:00 Fin :	19:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Tour préliminaire - Femmes et hommes (2 matchs) Lucky Loser - Femmes ou hommes (1 match)
#
#
#
#
#
#
#
# Session	VBV24
#
#
#
# Début :	21:00 Fin :	00:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Lucky Losers - Femmes et hommes (3 matchs)
#
#
#
#
#
# JOUR	9		Dimanch	4	Août
#
# Session		VBV25	Début :	09:00	Fin :	11:00	Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
#
#
# Session	VBV26
#
#
#
# Début :	13:00 Fin :	15:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
#
#
#
#
# Session	VBV27
#
#
#
# Début :	17:00 Fin :	19:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
#
#
#
#
# Session	VBV28
#
#
#
# Début :	21:00 Fin :	23:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
#
#
# JOUR	10		Lundi	5	Août
#
# Session		VBV29	Début :	09:00	Fin :	11:00	Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
# Session	VBV30
#
#
#
# Début :	13:00 Fin :	15:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
#
#
#
#
# Session	VBV31
#
#
#
# Début :	17:00 Fin :	19:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
#
#
#
#
# Session	VBV32
#
#
#
# Début :	21:00 Fin :	23:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# 8e de finale - Femmes et hommes (2 matchs)
#
#
#
#
#
# JOUR	11		Mardi	6	Août
#
# Session		VBV33	Début :	17:00	Fin :	19:00	Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Quarts de finales - Femmes et hommes (2 matchs)
#
#
#
#
#
# Session	VBV34
#
#
#
# Début :	21:00 Fin :	23:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Quarts de finales - Femmes et hommes (2 matchs)
#
#
#
#
#
# JOUR	12		Mercredi	7	Août
#
# Session		VBV35	Début :	17:00	Fin :	19:00	Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Quarts de finales - Femmes et hommes (2 matchs)
#
#
#
#
#
# Session	VBV36
#
#
#
# Début :	21:00 Fin :	23:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Quarts de finales - Femmes et hommes (2 matchs)
#
#
#
#
#
# JOUR	13		Jeudi	8	Août
#
# Session		VBV37	Début :	17:00	Fin :	19:00	Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Demi-finales - Femmes et hommes (2 matchs)
#
#
#
#
#
# Session	VBV38
#
#
#
# Début :	21:00 Fin :	23:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Demi-finales - Femmes et hommes (2 matchs)
#
#
#
#
#
# JOUR	14	Vendredi	9	Août
#
# Session		 VBV39	 Début :	21:00	Fin :	00:00	Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Match pour la médaille de bronze - Femmes
#
# Match pour la médaille d'or - Femmes
#
#
#
# Session	 VBV40	 Début :	21:00 Fin :	00:00 Stade Tour Eiffel
#
# Nom de l'épreuve/des épreuves
#
# Match pour la médaille de bronze - Hommes
#
#  Match pour la médaille d'or - Hommes
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# VOLLEYBALL
#
# Calendrier par épreuves
#
#
#
# Version :
#
#
#
#
#
# Session	VVO01
#
#
#
# 1,1
#
#
#
#
#
#
#
#
#
# Début:	09:00 Fin:	11:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO02
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO03
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO04
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
# JOUR	2		Dimanch	28	Juillet
#
# Session		VVO05	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# Session	VVO06
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO07
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
# Session	VVO08
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
# JOUR	3		Lundi	29	Juillet
#
# Session		VVO09	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# Session	VVO10
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO11
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO12
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# JOUR	4		Mardi	30	Juillet
#
# Session		VVO13	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
# Session	VVO14
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO15
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO16
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
# JOUR	5		Mercredi	31	Juillet
#
# Session		VVO17	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
# Session	VVO18
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO19
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO20
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# JOUR	6		Jeudi	1	Août
#
# Session		VVO21	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# Session	VVO22
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO23
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO24
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# JOUR	7		Vendredi	2	Août
#
# Session		VVO25	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
# Session	VVO26
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO27
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO28
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
# JOUR	8		Samedi	3	Août
#
# Session		VVO29	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# Session	VVO30
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO31
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO32
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Eliminatoires
#
#
#
#
#
# JOUR	9		Dimanch	4	Août
#
# Session		VVO33	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
# Session	VVO34
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO35
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
#
#
# Session	VVO36
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Eliminatoires
#
#
#
#
#
# JOUR	10		Lundi	5	Août
#
# Session		VVO37	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Quart de finale
#
#
#
#
#
# Session	VVO38
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Quart de finale
#
#
#
#
#
#
#
# Session	VVO39
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Quart de finale
#
#
#
#
#
#
#
# Session	VVO40
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Quart de finale
#
#
#
#
#
# JOUR	11		Mardi	6	Août
#
# Session		VVO41	Début:	09:00	Fin:	11:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Quart de finale
#
#
#
#
#
# Session	VVO42
#
#
#
# Début:	13:00 Fin:	15:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Quart de finale
#
#
#
#
#
#
#
# Session	VVO43
#
#
#
# Début:	17:00 Fin:	19:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Quart de finale
#
#
#
#
#
#
#
# Session	VVO44
#
#
#
# Début:	21:00 Fin:	23:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Quart de finale
#
#
#
#
#
# JOUR	12		Mercredi	7	Août
#
# Session		VVO45	Début:	16:00	Fin:	18:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Demi-finale
#
#
#
#
#
# Session	VVO46
#
#
#
# Début:	20:00 Fin:	22:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Demi-finale
#
#
#
#
#
#
#
# JOUR	13		Jeudi	8	Août
#
# Session		VVO47	Début:	16:00	Fin:	18:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Demi-finale
#
#
#
#
#
# Session	VVO48
#
#
#
# Début:	20:00 Fin:	22:30 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Demi-finale
#
#
#
#
#
# JOUR	14		Vendredi	9	Août
#
# Session		VVO49	Début:	16:00	Fin:	18:30	Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Hommes, Match pour la médaille de bronze
#
#
#
# JOUR	15	Samedi	10	Août
#
# Session		 VVO50	 Début:	13:00	Fin:	15:45	Arena Paris Sud 1
#
#
#
# Nom de l'épreuve/des épreuves
#
#  Hommes, Match pour la médaille d'or
#
#
#
#
#
# Session	VVO51
#
#
#
# Début:	17:15 Fin:	19:45 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, Match pour la médaille de bronze
#
#
#
#
#
#
#
# Session	 VVO52	 Début:	13:00 Fin:	15:45 Arena Paris Sud 1
#
# Nom de l'épreuve/des épreuves
#
#  Femmes, Match pour la médaille d'or
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# VTT
#
# Calendrier par épreuves
#
# Version :	1
#
#
#
# Session
#
#
#
#
#
#
#
# Début: 14:00 Fin:	16:30	Colline d'Elancourt
#
# Nom de l'épreuve/des épreuves
#
#  Cross-country - femmes
#
#
#
#
#
#
#
#
#
#
#
# Session	 MTB02	 Début: 14:00 Fin:	16:30	Colline d'Elancourt
#
# Nom de l'épreuve/des épreuves
#
#  Cross-country - hommes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #C1-INTERNAL
#
#
#
# Le calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.
#
# WATER POLO
#
# Calendrier par épreuves
#
# Version :	1
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
# Session	WPO02
#
#
#
#
#
# Début :	18:30 Fin :	21:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	2		Dimanche	28	Juillet
#
# Session		WPO03	Début :	10:30	Fin :	13:30	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO04
#
#
#
# Début :	15:00 Fin :	18:00 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
#
#
# Session	WPO05
#
#
#
# Début :	19:30 Fin :	22:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	3		Lundi	29	Juillet
#
# Session		WPO06	Début :	14:00	Fin :	17:00	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO07
#
#
#
# Début :	18:30 Fin :	21:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	4		Mardi	30	Juillet
#
# Session		WPO08	Début :	10:30	Fin :	13:30	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO09
#
#
#
# Début :	15:00 Fin :	18:00 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
#
#
# Session	WPO10
#
#
#
# Début :	19:30 Fin :	22:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	5		Mercredi	31	Juillet
#
# Session		WPO11	Début :	14:00	Fin :	17:00	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO12
#
#
#
# Début :	18:30 Fin :	21:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	6		Jeudi	1	Août
#
# Session		WPO13	Début :	10:30	Fin :	13:30	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO14
#
#
#
# Début :	15:00 Fin :	18:00 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
#
#
# Session	WPO15
#
#
#
# Début :	19:30 Fin :	22:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	7		Vendredi	2	Août
#
# Session		WPO16	Début :	14:00	Fin :	17:00	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
#
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO17
#
#
#
# Début :	18:30 Fin :	21:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	8		Samedi	3	Août
#
# Session		WPO18	Début :	10:30	Fin :	13:30	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO19
#
#
#
# Début :	15:00 Fin :	18:00 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
#
#
# Session	WPO20
#
#
#
# Début :	19:30 Fin :	22:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	9		Dimanche	4	Août
#
# Session		WPO21	Début :	14:00	Fin :	17:00	Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# Session	WPO22
#
#
#
# Début :	18:30 Fin :	21:30 Centre aquatique
#
# Nom de l'épreuve/des épreuves
#
# Femmes, tour préliminaire (2 matchs)
#
#
#
#
#
# JOUR	10		Lundi	5	Août
#
# Session		WPO23	Début :	12:00	Fin :	16:30	Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (3 matchs)
#
#
#
#
#
# Session	WPO24
#
#
#
# Début :	18:30 Fin :	23:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Hommes, tour préliminaire (3 matchs)
#
#
#
#
#
#
#
# JOUR	11		Mardi	6	Août
#
# Session		WPO25	Début :	14:00	Fin :	17:00	Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Femmes, quarts de finale (2 matchs)
#
#
#
#
#
# Session	WPO26
#
#
#
# Début :	19:00 Fin :	22:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Femmes, quarts de finale (2 matchs)
#
#
#
#
#
# JOUR	12		Mercredi	7	Août
#
# Session		WPO27	Début :	14:00	Fin :	17:00	Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Hommes, quarts de finale (2 matchs)
#
#
#
#
#
# Session	WPO28
#
#
#
# Début :	19:00 Fin :	22:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Hommes, quarts de finale (2 matchs)
#
#
#
#
#
# JOUR	13		Jeudi	8	Août
#
# Session		WPO29	Début :	13:00	Fin :	16:00	Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves Femmes, match de classement Femmes, demi-finale
#
#
#
#
#
# Session	WPO30
#
#
#
# Début :	18:00 Fin :	21:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves Femmes, match de classement Femmes, demi-finale
#
#
#
#
#
# JOUR	14		Vendredi	9	Août
#
# Session		WPO31	Début :	13:00	Fin :	16:00	Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves Hommes, match de classement Hommes, demi-finale
#
#
#
#
#
# Session	WPO32
#
#
#
# Début :	18:00 Fin :	21:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Hommes, match de classement
#
#
#
# Hommes, demi-finale
#
#
#
#
#
#
#
# Session	WPO33
#
#
#
# Début :	09:00 Fin :	12:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Femmes, match de classement
#
# Femmes, match pour la médaille de bronze
#
#
#
#
#
# Session	 WPO34	 Début :	14:00 Fin :	21:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Femmes, match de classement
#
#  Femmes, match pour la médaille d'or	 Hommes, match de classement
#
#
#
# JOUR	16		Dimanche	11	Août
#
# Session		WPO35	Début :	09:00	Fin :	12:00 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
# Hommes, match de classement
#
# Hommes, match pour la médaille de bronze
#
#
#
# Session	 WPO36	 Début :	14:00 Fin :	15:50 Paris La Défense Arena
#
# Nom de l'épreuve/des épreuves
#
#  Hommes, match pour la médaille d'or

# %%
words[20:24]
# Out:
# []

# %%
import pandas as pd

words = []
for line in lines:
    words += line.split()
    
demarq1_discipline = "calendrier reste susceptible de modification jusqu'à la conclusion des Jeux Olympiques.".split()
demarq2_discipline = "A noter que l'ordre des matchs sera déterminé pendant les Jeux en fonction du temps de repos des athlètes, des demandes des diffuseurs et d'autres paramètres qu'il n'est pas possible d'anticip".split()
discipline = 'ATHLETISME'

data = []
i = 0
while i < (len(words)):
    word = words[i]        
    if words[i].upper() == "JOUR":
        if len(words) > i + 4:
            jour = words[i+1]
            date = words[i+2] + " " + words[i+3] + " " + words[i+4]
            i +=4
        else:
            erreur.append(line)
    
    # discipline
    if words[i:i+len(demarq1_discipline)] == demarq1_discipline:
        i+=len(demarq1_discipline)
        if words[i:i+len(demarq2_discipline)] == demarq2_discipline:
            i+=len(demarq2_discipline)
        discipline = ""
        espace = ""
        while words[i] != "Calendrier":
            discipline += espace + words[i]
            espace = " "
            i += 1
    
    if words[i] == "Session":
        session = words[i+1]
        i += 2
    if words[i] == "Début":
        debut = words[i+2]
        i += 3
    if words[i] == "Fin":
        fin = words[i+2]
        i += 3
        lieu_epreuve = ""
        espace = ""
        while words[i] != "Nom":
            lieu_epreuve += espace + words[i]
            espace = " "
            i += 1
    nom_epreuve = ""
    if words[i:i+4] == ['Nom', 'de', "l'épreuve/des", 'épreuves']:
        i += 4
        espace = ""
        while len(words) > i and words[i].upper() not in ["JOUR", "SESSION"] and words[i:i+2] != ['Le', 'calendrier']:
            nom_epreuve += espace + words[i]
            espace = " "
            i += 1
        data.append([jour, date, discipline, session, debut, fin, lieu_epreuve, nom_epreuve])
    i += 1

def traitement_discipline(string):
    if len(string) == 0:
        return ""
    else:
        return string[0].upper() + string[1:].lower()


df = pd.DataFrame(data, columns=['num_jour', 'date', 'discipline', 'num_session', 'debut_epreuve', 'fin_epreuve', 'lieu_epreuve', 'nom_epreuve'])
df['discipline'] = df['discipline'].apply(traitement_discipline)
#df.to_csv('../data/session_planning_olympics.csv')
# Out:
# C:\Users\coren\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\coren\anaconda3\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# C:\Users\coren\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
def traitement_discipline(string):
    if len(string) == 0:
        return ""
    else:
        return string[0].upper() + string[1:].lower()

df['discipline'].apply(traitement_discipline)
# Out:
# 0      Athletisme
# 1      Athletisme
# 2      Athletisme
# 3      Athletisme
# 4      Athletisme
#           ...
# 730    Water polo
# 731    Water polo
# 732    Water polo
# 733    Water polo
# 734    Water polo
# Name: discipline, Length: 735, dtype: object

# %%
string = "ATHDB"
string[0].upper() + string[1:].lower()
# Out:
# 'Athdb'

# %%
df
# Out:
#     num_jour               date  discipline num_session debut_epreuve  \
# 0          6       Jeudi 1 Août  Athletisme       ATH01         07:30
# 1          6       Jeudi 1 Août  Athletisme       ATH02         10:00
# 2          6       Jeudi 1 Août  Athletisme       ATH02         17:40
# 3          6       Jeudi 1 Août  Athletisme       ATH04         10:00
# 4          6       Jeudi 1 Août  Athletisme       ATH04         19:00
# ..       ...                ...         ...         ...           ...
# 730        1  Samedi 27 Juillet  Water polo       WPO31         18:00
# 731        1  Samedi 27 Juillet  Water polo       WPO31         09:00
# 732        1  Samedi 27 Juillet  Water polo       WPO31         14:00
# 733        1  Samedi 27 Juillet  Water polo       WPO35         09:00
# 734        1  Samedi 27 Juillet  Water polo       WPO35         14:00
#
#     fin_epreuve            lieu_epreuve  \
# 0         11:05               Trocadéro
# 1         13:00         Stade de France
# 2         22:00         Stade de France
# 3         16:00         Stade de France
# 4         22:00         Stade de France
# ..          ...                     ...
# 730       21:00  Paris La Défense Arena
# 731       12:00  Paris La Défense Arena
# 732       21:00  Paris La Défense Arena
# 733       12:00  Paris La Défense Arena
# 734       15:50  Paris La Défense Arena
#
#                                            nom_epreuve
# 0
# 1    Décathlon - 100 m, hommes Lancer de marteau - ...
# 2    Décathlon - saut en hauteur, hommes 5 000 m - ...
# 3    Décathlon - 110 m haies, hommes Saut à la perc...
# 4    1 500 m - hommes, Repêchages Lancer de poids -...
# ..                                                 ...
# 730    Hommes, match de classement Hommes, demi-finale
# 731  Femmes, match de classement Femmes, match pour...
# 732  Femmes, match de classement Femmes, match pour...
# 733  Hommes, match de classement Hommes, match pour...
# 734                Hommes, match pour la médaille d'or
#
# [735 rows x 8 columns]

# %%
separateurs = [' - ', ', ']
noms = ['epreuve', 'genre', 'etape']

# %%
import json

def parser(texte, separateurs, noms):
    epreuves = {'content' : []}
    # epreuves = []
    # epreuve, genre, etape = '', '', ''
    dico_epreuve = {}
    i, i0 = 0, 0
    while i < len(texte):
        for n in range(len(separateurs)):
            separateur = separateurs[n]
            while i < len(texte):
                if i + len(separateur) < len(texte) and texte[i:i+len(separateur)] == separateur:
                    dico_epreuve[noms[n]] = texte[i0:i]
                    i+=len(separateur)
                    i0 = i
                    break
                i+=1
        while i < len(texte):
            if texte[i].isupper():
                dico_epreuve[noms[-1]] = texte[i0:i-1]
                i0 = i
                break
            i+=1
        epreuves['content'].append(dico_epreuve.copy())#json.dumps(dico_epreuve.copy()))
        # epreuves.append(dico_epreuve.copy())
        i+=1
    return json.dumps(epreuves)

noms_sports = [
    "100 m",
    "200 m",
    "1 500 m",
    "5 000 m",
    "800 m",
    "10 000 m",
    "3 000 m",
    "400 m",
    "110 m",
    "50kg",
    "51kg",
    "54kg",
    "60kg",
    "66kg",
    "75kg",
    "63.5kg",
    "63,5kg",
    "80kg",
    "92kg",
    "71kg",
    "57kg",
    "+92kg"
]

noms_etapes = ["eliminatoires", "repêchage"] # --> enlever majuscule

# Rajouter condition sur nom sport: plus de 3 lettres
# pour tej les "finale A/B" et autres

cles_parsers = {
    'ATH ROW BMF CTR CLB FEN SWN ARC SHO BOX CSL CSP WRE' : {
            'separateurs' : [' - ', ', '], 
            'noms' : ['epreuve', 'genre', 'etape']
    }, 
    'BKB BMX  BK3 RU7 BKG GTR HBL HOC SRF TTE VVO WPO' : {
        'separateurs' : [', '], 
        'noms' : ['genre', 'etape']
    },
    'CRD OWS DIV MTB' : {
        'separateurs' : [' - '], 
        'noms' : ['epreuve', 'genre']
    },
    'FBL' : {
        'separateurs' : [', ', ' - '], 
        'noms' : ['genre', 'etape', 'epreuve']
    },
    'GAR VBV' : {
        'separateurs' : [' - '], 
        'noms' : ['etape', 'genre']
    },
    'GRY BDM' : {
        'separateurs' : [', '], 
        'noms' : ['epreuve', 'etape']
    },
    'WLF' : {
        'separateurs' : [' - '], 
        'noms' : ['epreuve', 'genre']
    },
    'SWA EQU TKW TEN' : {
        'separateurs' : [], 
        'noms' : ['epreuve']
    },
    'WLF' : {
        'separateurs' : [], 
        'noms' : ['genre']
    },
}


def match_cle_parser(code_disc, cles_parsers):
    for cle in cles_parsers.keys():
        if code_disc in cle:
            return cles_parsers[cle]
    print(f"Cette discipline n'est pas prise en charge : {code_disc}")

def parsing_epreuve(row):
    texte = row.nom_epreuve
    if len(str(row.num_session)) > 2:
        disc = str(row.num_session)[:3]
        cle_parser = match_cle_parser(disc, cles_parsers)
        if cle_parser is not None:
            return parser(texte, cle_parser['separateurs'], cle_parser['noms'])

# disc_analysees = ['ATHLETISME', 'AVIRON', 'BASKETBALL', 'BASKETBALL 3x3', 'BMX FREESTYLE', 'BMX RACING', 'Breaking']

df['parsing_epreuve'] = df.apply(parsing_epreuve, axis=1)
#df.to_csv('../data/session_planning_olympics6.csv')
# df
# Out:
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Box
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : GLF
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : JUD
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : SWM
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : MPN
# Cette discipline n'est pas prise en charge : MPN
# Cette discipline n'est pas prise en charge : MPN
# Cette discipline n'est pas prise en charge : MPN
# Cette discipline n'est pas prise en charge : MPN
# Cette discipline n'est pas prise en charge : TRI
# Cette discipline n'est pas prise en charge : TRI
# Cette discipline n'est pas prise en charge : TRI
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : SAL
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Déb
# Cette discipline n'est pas prise en charge : Déb

# %%
# disciplines ou le ", " ne marche pas comme séparateur
# CRD BKB 

for i in range(len(df)):
    print(df['discipline'][i], df['parsing_epreuve'][i]) #["content"]
# Out:
# Athletisme {"content": [{"epreuve": "20 km marche", "genre": "hommes"}]}
# Athletisme {"content": [{"epreuve": "D\u00e9cathlon", "genre": "100 m", "etape": "hommes"}, {"epreuve": "Lancer de marteau", "genre": "hommes", "etape": "qualifications"}, {"epreuve": "Saut en hauteur", "genre": "femmes", "etape": "qualifications 100 m - femmes, tour pr\u00e9liminaire"}, {"epreuve": "D\u00e9cathlon", "genre": "saut en longueur", "etape": "hommes 1 500 m - hommes, 1er tour 100 m - femmes, 1er tour"}, {"epreuve": "D\u00e9cathlon", "genre": "lancer de poids", "etape": "hommes 1 500 m - hommes, 1er tour 100 m - femmes, 1er tour"}]}
# Athletisme {"content": [{"epreuve": "D\u00e9cathlon", "genre": "saut en hauteur", "etape": "hommes 5 000 m - femmes, 1er tour"}, {"epreuve": "Triple saut", "genre": "femmes", "etape": "qualifications"}, {"epreuve": "Lancer de disque", "genre": "femmes", "etape": "qualifications"}, {"epreuve": "Relais 4 x 400 m", "genre": "mixte", "etape": "1er tour 800 m - femmes, 1er tour"}, {"epreuve": "Lancer de poids", "genre": "hommes", "etape": "qualifications"}, {"epreuve": "D\u00e9cathlon", "genre": "400 m", "etape": "qualifications"}]}
# Athletisme {"content": [{"epreuve": "D\u00e9cathlon", "genre": "110 m haies", "etape": "hommes"}, {"epreuve": "Saut \u00e0 la perche", "genre": "hommes", "etape": "qualifications 100 m - hommes, tour pr\u00e9liminaire"}, {"epreuve": "D\u00e9cathlon", "genre": "lancer de disque", "etape": "hommes 800 m - femmes,"}, {"epreuve": "Rep\u00eachages 100 m", "genre": "hommes", "etape": "1er tour"}, {"epreuve": "D\u00e9cathlon", "genre": "saut \u00e0 la perche", "etape": "1er tour"}]}
# Athletisme {"content": [{"epreuve": "1 500 m", "genre": "hommes", "etape": ""}, {"epreuve": "Rep\u00eachages Lancer de poids", "genre": "hommes", "etape": "finale 100 m - femmes, demi-finales"}, {"epreuve": "D\u00e9cathlon", "genre": "lancer de javelot", "etape": "hommes"}, {"epreuve": "D\u00e9cathlon", "genre": "1 500 m", "etape": "hommes"}]}
# Athletisme {"content": [{"epreuve": "3 000 m steeple", "genre": "femmes", "etape": "1er tour"}, {"epreuve": "Lancer de marteau", "genre": "femmes", "etape": "qualifications 200 m - femmes, 1er tour"}, {"epreuve": "Saut en longueur", "genre": "hommes", "etape": "qualifications 200 m - femmes, 1er tour"}]}
# Athletisme {"content": [{"epreuve": "400 m", "genre": "hommes", "etape": "1er tour 100 m - hommes, demi-finales 800 m - femmes, demi-finales 1 500 m - hommes, demi-finales"}, {"epreuve": "Saut en hauteur", "genre": "femmes", "etape": "finale"}, {"epreuve": "Lancer de marteau", "genre": "hommes", "etape": "finale"}]}
# Athletisme {"content": [{"epreuve": "400 m haies", "genre": "hommes", "etape": "1er tour"}, {"epreuve": "Lancer de disque", "genre": "hommes", "etape": "qualifications"}, {"epreuve": "Saut \u00e0 la perche", "genre": "femmes", "etape": "qualifications 400 m haies - femmes,"}, {"epreuve": "Rep\u00eachages 400 m", "genre": "hommes", "etape": ""}, {"epreuve": "Rep\u00eachages 400 m", "genre": "femmes", "etape": "1er tour 200 m - femmes,"}, {"epreuve": "Rep\u00eachages 400 m", "genre": "femmes", "etape": "1er tour 200 m - femmes,"}]}
# Athletisme {"content": [{"epreuve": "3 000 m steeple", "genre": "hommes"}]}
# Athletisme {"content": [{"epreuve": "1 500 m", "genre": "femmes", "etape": "1er tour"}, {"epreuve": "Lancer de javelot", "genre": "hommes", "etape": "qualifications 110 m haies - hommes,"}, {"epreuve": "Rep\u00eachages Saut en longueur", "genre": "femmes", "etape": "qualifications 400 m - femmes,"}, {"epreuve": "Rep\u00eachages 400 m haies", "genre": "hommes", "etape": ""}, {"epreuve": "Rep\u00eachages 200 m", "genre": "hommes", "etape": ""}, {"epreuve": "Rep\u00eachages 200 m", "genre": "hommes", "etape": ""}]}
# Athletisme {"content": [{"epreuve": "400 m", "genre": "hommes"}]}
# Athletisme {"content": []}
# Athletisme None
# Athletisme {"content": [{"epreuve": "Heptathlon", "genre": "100 m haies", "etape": "femmes"}, {"epreuve": "Lancer de poids", "genre": "femmes", "etape": "qualifications 100 m haies - femmes,"}, {"epreuve": "Rep\u00eachages Heptathlon", "genre": "saut en hauteur", "etape": "femmes"}, {"epreuve": "Relais 4 x 100 m", "genre": "femmes", "etape": "1er tour"}, {"epreuve": "Relais 4 x 100 m", "genre": "hommes", "etape": "1er tour 800 m - hommes,"}, {"epreuve": "Relais 4 x 100 m", "genre": "hommes", "etape": "1er tour 800 m - hommes,"}]}
# Athletisme {"content": [{"epreuve": "Heptathlon", "genre": "lancer de poids", "etape": "femmes 1 500 m - femmes, demi-finales"}, {"epreuve": "Heptathlon", "genre": "200 m", "etape": "femmes 1 500 m - femmes, demi-finales"}]}
# Athletisme {"content": [{"epreuve": "Heptathlon", "genre": "saut en longueur", "etape": "femmes"}, {"epreuve": "Relais 4 x 400 m", "genre": "femmes", "etape": "1er tour"}, {"epreuve": "Relais 4 x 400 m", "genre": "hommes", "etape": "1er tour"}, {"epreuve": "Heptathlon", "genre": "lancer de javelot", "etape": "1er tour"}]}
# Athletisme {"content": []}
# Athletisme {"content": [{"epreuve": "Marathon", "genre": "hommes"}]}
# Athletisme {"content": []}
# Athletisme {"content": [{"epreuve": "Marathon", "genre": "femmes"}]}
# Aviron {"content": [{"epreuve": "Skiff", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Skiff", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Deux de couple", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Deux de couple", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Quatre de couple", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Quatre de couple", "genre": "femmes", "etape": "\u00e9liminatoires"}]}
# Aviron {"content": [{"epreuve": "Skiff", "genre": "femmes", "etape": "rep\u00eachages"}, {"epreuve": "Skiff", "genre": "hommes", "etape": "rep\u00eachages"}, {"epreuve": "Deux de couple", "genre": "femmes", "etape": "rep\u00eachage"}, {"epreuve": "Deux de couple", "genre": "hommes", "etape": "rep\u00eachage"}, {"epreuve": "Deux de pointe sans barreur", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Deux de pointe sans barreur", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Deux de couple poids l\u00e9ger", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Deux de couple poids l\u00e9ger", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Quatre de pointe sans barreur", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Quatre de pointe sans barreur", "genre": "hommes", "etape": "\u00e9liminatoires"}]}
# Aviron {"content": [{"epreuve": "Skiff", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "E/F Skiff", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "E/F Deux de pointe sans barreur", "genre": "hommes", "etape": "rep\u00eachage"}, {"epreuve": "Deux de pointe sans barreur", "genre": "femmes", "etape": "rep\u00eachage"}, {"epreuve": "Deux de couple poids l\u00e9ger", "genre": "hommes", "etape": "rep\u00eachages"}, {"epreuve": "Deux de couple poids l\u00e9ger", "genre": "femmes", "etape": "rep\u00eachages"}, {"epreuve": "Quatre de couple", "genre": "hommes", "etape": "rep\u00eachage"}, {"epreuve": "Quatre de couple", "genre": "femmes", "etape": "rep\u00eachage"}, {"epreuve": "Huit de pointe avec barreur", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Huit de pointe avec barreur", "genre": "femmes", "etape": "\u00e9liminatoires"}]}
# Aviron {"content": [{"epreuve": "Skiff", "genre": "femmes", "etape": "quarts de finale"}, {"epreuve": "Skiff", "genre": "hommes", "etape": "quarts de finale"}, {"epreuve": "Deux de couple", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Deux de couple", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Quatre de pointe sans barreur", "genre": "femmes", "etape": "rep\u00eachage"}, {"epreuve": "Quatre de pointe sans barreur", "genre": "hommes", "etape": "rep\u00eachage"}]}
# Aviron {"content": [{"epreuve": "Deux de couple poids l\u00e9ger", "genre": "femmes", "etape": "finale"}, {"epreuve": "C Deux de couple poids l\u00e9ger", "genre": "hommes", "etape": "finale"}, {"epreuve": "C Skiff", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "C/D Skiff", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "C/D Deux de pointe sans barreur", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Deux de pointe sans barreur", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Deux de couple poids l\u00e9ger", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Deux de couple poids l\u00e9ger", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Quatre de couple", "genre": "hommes", "etape": "finale"}, {"epreuve": "B Quatre de couple", "genre": "femmes", "etape": "finale"}]}
# Aviron {"content": [{"epreuve": "Skiff", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "A/B Skiff", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "A/B Huit de pointe avec barreur", "genre": "femmes", "etape": "rep\u00eachage"}, {"epreuve": "Huit de pointe avec barreur", "genre": "hommes", "etape": "rep\u00eachage"}, {"epreuve": "Deux de couple", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Deux de couple", "genre": "hommes", "etape": "finale"}, {"epreuve": "B Quatre de pointe sans barreur", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Quatre de pointe sans barreur", "genre": "hommes", "etape": "finale"}]}
# Aviron {"content": [{"epreuve": "Skiff", "genre": "hommes", "etape": "finale"}, {"epreuve": "F Skiff", "genre": "femmes", "etape": "finale"}, {"epreuve": "F Skiff", "genre": "hommes", "etape": "finale"}, {"epreuve": "E Skiff", "genre": "femmes", "etape": "finale"}, {"epreuve": "E Skiff", "genre": "hommes", "etape": "finale"}, {"epreuve": "D Skiff", "genre": "femmes", "etape": "finale"}, {"epreuve": "D Deux de pointe sans barreur", "genre": "hommes", "etape": "finale"}, {"epreuve": "B Deux de pointe sans barreur", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Deux de couple poids l\u00e9ger", "genre": "hommes", "etape": "finale"}, {"epreuve": "B Deux de couple poids l\u00e9ger", "genre": "femmes", "etape": "finale"}]}
# Aviron {"content": [{"epreuve": "Skiff", "genre": "femmes", "etape": "finale"}, {"epreuve": "C Skiff", "genre": "hommes", "etape": "finale"}, {"epreuve": "C Skiff", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Skiff", "genre": "hommes", "etape": "finale"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Simple hommes", "etape": "poules pr\u00e9liminaires"}, {"epreuve": "Double mixte", "etape": "poules pr\u00e9liminaires"}]}
# Badminton {"content": [{"epreuve": "Double femmes", "etape": "quarts de finale"}, {"epreuve": "Simple hommes", "etape": "quarts de finale"}]}
# Badminton {"content": [{"epreuve": "Double hommes", "etape": "quarts de finale"}, {"epreuve": "Simple hommes", "etape": "quarts de finale"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "8e de finale"}, {"epreuve": "Double mixte", "etape": "8e de finale"}]}
# Badminton {"content": [{"epreuve": "Double femmes", "etape": "demi-finale"}, {"epreuve": "Double hommes", "etape": "demi-finale"}]}
# Badminton {"content": [{"epreuve": "Double mixte", "etape": "match bronze"}, {"epreuve": "Simple hommes", "etape": "match bronze"}]}
# Badminton {"content": [{"epreuve": "Simple femmes"}]}
# Badminton {"content": [{"epreuve": "Double femmes"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "demi-finales"}, {"epreuve": "Simple hommes", "etape": "demi-finales"}]}
# Badminton {"content": [{"epreuve": "Double hommes", "etape": "match bronze"}, {"epreuve": "Double hommes", "etape": "match bronze"}]}
# Badminton {"content": [{"epreuve": "Simple femmes", "etape": "match bronze"}, {"epreuve": "Simple femmes", "etape": "match bronze"}]}
# Badminton {"content": [{"epreuve": "Simple hommes", "etape": "match bronze"}, {"epreuve": "Simple hommes", "etape": "match or "}, {"epreuve": "Simple hommes", "etape": "match or "}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes ou Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes", "etape": "quart de finale"}, {"genre": "D\u00e9but: 18:00 Fin: 20:00 Arena Bercy Nom de l'\u00e9preuve/des \u00e9preuves Hommes", "etape": "quart de finale"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes", "etape": "quart de finale"}, {"genre": "D\u00e9but: 18:00 Fin: 20:00 Arena Bercy Nom de l'\u00e9preuve/des \u00e9preuves Femmes", "etape": "quart de finale"}, {"genre": "D\u00e9but: 21:30 Fin: 23:30 Arena Bercy Nom de l'\u00e9preuve/des \u00e9preuves Femmes", "etape": "quart de finale"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Hommes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball {"content": [{"genre": "Femmes"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "matches de poule (2 matchs)"}, {"genre": "Hommes", "etape": "matches de poule (2 matchs)"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes"}]}
# Basketball 3x3 {"content": [{"genre": "Hommes"}]}
# Basketball 3x3 {"content": [{"genre": "Hommes"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes et hommes"}]}
# Basketball 3x3 {"content": [{"genre": "Femmes", "etape": "match pour la m\u00e9daille de bronze"}, {"genre": "Hommes", "etape": "match pour la m\u00e9daille de bronze"}]}
# Bmx freestyle {"content": [{"genre": "Park - femmes", "etape": "qualification"}, {"genre": "Park - hommes", "etape": "qualification"}]}
# Bmx freestyle {"content": [{"genre": "Park - femmes", "etape": "finale"}, {"genre": "Park - hommes", "etape": "finale"}]}
# Bmx racing {"content": [{"genre": "Hommes", "etape": "quarts de finale"}, {"genre": "Femmes", "etape": "quarts de finale"}, {"genre": "Hommes", "etape": "tour de la derni\u00e8re chance"}, {"genre": "Femmes", "etape": "tour de la derni\u00e8re chance"}]}
# Bmx racing {"content": [{"genre": "Hommes", "etape": "demi-finales"}, {"genre": "Femmes", "etape": "demi-finales"}]}
# Breaking {"content": [{"genre": "Femmes"}]}
# Breaking {"content": [{"genre": "Femmes"}]}
# Breaking {"content": [{"genre": "Hommes"}]}
# Breaking {"content": [{"genre": "Hommes"}]}
# Boxe {"content": [{"epreuve": "54kg", "genre": "Femmes", "etape": "1/32 finale combat 1 54kg -"}, {"epreuve": "Femmes, 1/32 finale combat 2 54kg", "genre": "Femmes", "etape": "1/32 finale combat 3 60kg -"}, {"epreuve": "Femmes, 1/32 finale combat 1 60kg", "genre": "Femmes", "etape": "1/32 finale combat 2 60kg -"}, {"epreuve": "Femmes, 1/32 finale combat 3 63.5kg", "genre": "Hommes", "etape": "1/32 finale combat 1 63.5kg -"}, {"epreuve": "Hommes, 1/32 finale combat 2 80kg", "genre": "Hommes", "etape": "1/32 finale combat 1 63.5kg -"}]}
# Boxe {"content": [{"epreuve": "54kg", "genre": "Femmes", "etape": "1/32 finale combat 4 54kg -"}, {"epreuve": "Femmes, 1/32 finale combat 5 54kg", "genre": "Femmes", "etape": "1/32 finale combat 6 60kg -"}, {"epreuve": "Femmes, 1/32 finale combat 4 60kg", "genre": "Femmes", "etape": "1/32 finale combat 5 60kg -"}, {"epreuve": "Femmes, 1/32 finale combat 6 63.5kg", "genre": "Hommes", "etape": "1/32 finale combat 3 63.5kg -"}, {"epreuve": "Hommes, 1/32 finale combat 4 80kg", "genre": "Hommes", "etape": "1/32 finale combat 3 63.5kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Hommes", "etape": "1/32 finale combat 1 71kg -"}, {"epreuve": "Hommes, 1/32 finale, combat 1 71kg", "genre": "Hommes", "etape": "1/32 finale, combat 2 92kg -"}, {"epreuve": "Hommes, 1/16 finale, combat 1 92kg", "genre": "Hommes", "etape": "1/16 finale, combat 2 50kg -"}, {"epreuve": "Femmes, 1/32 finale combat 1 50kg", "genre": "Femmes", "etape": "1/32 finale combat 2 66kg -"}, {"epreuve": "Femmes, 1/32 finale combat 1 50kg", "genre": "Femmes", "etape": "1/32 finale combat 2 66kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Hommes", "etape": "1/32 finale combat 2 71kg -"}, {"epreuve": "Hommes, 1/32 finale, combat 3 92kg", "genre": "Hommes", "etape": "1/16 finale, combat 3 92kg -"}, {"epreuve": "Hommes, 1/16 finale, combat 4 92kg", "genre": "Hommes", "etape": "1/16 finale, combat 4 50kg -"}, {"epreuve": "Femmes, 1/32 finale combat 3 50kg", "genre": "Femmes", "etape": "1/32 finale combat 4 66kg -"}, {"epreuve": "Femmes, 1/32 finale combat 3 50kg", "genre": "Femmes", "etape": "1/32 finale combat 4 66kg -"}]}
# Boxe {"content": [{"epreuve": "71kg", "genre": "Hommes", "etape": "1/32 finale combat 4 92kg -"}, {"epreuve": "Hommes, 1/16 finale, combat 6 92kg", "genre": "Hommes", "etape": "1/16 finale, combat 7 92kg -"}, {"epreuve": "Hommes, 1/16 finale, combat 8 50kg", "genre": "Femmes", "etape": "1/32 finale combat 5 50kg -"}, {"epreuve": "Femmes, 1/32 finale combat 6 66kg", "genre": "Femmes", "etape": "1/32 finale combat 3 66kg -"}, {"epreuve": "Femmes, 1/32 finale combat 6 66kg", "genre": "Femmes", "etape": "1/32 finale combat 3 66kg -"}]}
# Boxe {"content": [{"epreuve": "60kg", "genre": "Femmes", "etape": "1/16 finale combat 7 60kg -"}, {"epreuve": "Femmes, 1/16 finale combat 8 60kg", "genre": "Femmes", "etape": "1/16 finale combat 9 63,5kg -"}, {"epreuve": "Hommes, 1/16 finale combat 5 63,5kg", "genre": "Hommes", "etape": "1/16 finale combat 6 63,5kg -"}, {"epreuve": "Hommes, 1/16 finale combat 7 +92kg", "genre": "Hommes", "etape": "1/16 finale combat 1 +92kg -"}, {"epreuve": "Hommes, 1/16 finale combat 7 +92kg", "genre": "Hommes", "etape": "1/16 finale combat 1 +92kg -"}]}
# Boxe {"content": [{"epreuve": "60kg", "genre": "Femmes", "etape": "1/16 finale combat 10 60kg -"}, {"epreuve": "Femmes, 1/16 finale combat 11 63,5kg", "genre": "Hommes", "etape": "1/16 finale combat 8 63,5kg -"}, {"epreuve": "Hommes, 1/16 finale combat 9 63,5kg", "genre": "Hommes", "etape": "1/16 finale combat 10 +92kg -"}, {"epreuve": "Hommes, 1/16 finale combat 3 +92kg", "genre": "Hommes", "etape": "1/16 finale combat 4 +92kg -"}, {"epreuve": "Hommes, 1/16 finale combat 3 +92kg", "genre": "Hommes", "etape": "1/16 finale combat 4 +92kg -"}]}
# Boxe {"content": [{"epreuve": "60kg", "genre": "Femmes", "etape": "1/16 finale combat 12 60kg -"}, {"epreuve": "Femmes, 1/16 finale combat 13 60kg", "genre": "Femmes", "etape": "1/16 finale combat 14 63,5kg -"}, {"epreuve": "Hommes, 1/16 finale combat 11 63,5kg", "genre": "Hommes", "etape": "1/16 finale combat 12 +92kg -"}, {"epreuve": "Hommes, 1/16 finale combat 6 +92kg", "genre": "Hommes", "etape": "1/16 finale combat 7 +92kg -"}, {"epreuve": "Hommes, 1/16 finale combat 6 +92kg", "genre": "Hommes", "etape": "1/16 finale combat 7 +92kg -"}]}
# Boxe {"content": [{"epreuve": "51kg", "genre": "Hommes", "etape": "1/16 finale combat 1 51kg -"}, {"epreuve": "Hommes, 1/16 finale combat 2 51kg", "genre": "Hommes", "etape": "1/16 finale combat 3 80kg -"}, {"epreuve": "Hommes, 1/16 finale combat 3 80kg", "genre": "Hommes", "etape": "1/16 finale combat 4 54kg -"}, {"epreuve": "Femmes, 1/16 finale combat 7 54kg", "genre": "Femmes", "etape": "1/16 finale combat 8 54kg -"}, {"epreuve": "Femmes, 1/16 finale combat 9 57kg", "genre": "Femmes", "etape": "1/32 finale combat 1 57kg -"}, {"epreuve": "Femmes, 1/16 finale combat 9 57kg", "genre": "Femmes", "etape": "1/32 finale combat 1 57kg -"}]}
# Boxe {"content": [{"epreuve": "51kg", "genre": "Hommes", "etape": "1/16 finale combat 4 51kg -"}, {"epreuve": "Hommes, 1/16 finale combat 5 51kg", "genre": "Hommes", "etape": "1/16 finale combat 6 80kg -"}, {"epreuve": "Hommes, 1/16 finale combat 5 80kg", "genre": "Hommes", "etape": "1/16 finale combat 6 54kg -"}, {"epreuve": "Femmes, 1/16 finale combat 10 54kg", "genre": "Femmes", "etape": "1/16 finale combat 11 54kg -"}, {"epreuve": "Femmes, 1/16 finale combat 12 57kg", "genre": "Femmes", "etape": "1/32 finale combat 3 57kg -"}, {"epreuve": "Femmes, 1/16 finale combat 12 57kg", "genre": "Femmes", "etape": "1/32 finale combat 3 57kg -"}]}
# Boxe {"content": [{"epreuve": "51kg", "genre": "Hommes", "etape": "1/16 finale combat 7 51kg -"}, {"epreuve": "Hommes, 1/16 finale combat 8 80kg", "genre": "Hommes", "etape": "1/16 finale combat 7 80kg -"}, {"epreuve": "Hommes, 1/16 finale combat 8 80kg", "genre": "Hommes", "etape": "1/16 finale combat 9 80kg -"}, {"epreuve": "Hommes, 1/16 finale combat 10 54kg", "genre": "Femmes", "etape": "1/16 finale combat 13 54kg -"}, {"epreuve": "Femmes, 1/32 finale combat 5 54kg", "genre": "Femmes", "etape": "1/16 finale combat 13 54kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Hommes", "etape": "1/16 finale combat 3 57kg -"}, {"epreuve": "Hommes, 1/16 finale combat 4 71kg", "genre": "Hommes", "etape": "1/16 finale combat 5 71kg -"}, {"epreuve": "Hommes, 1/16 finale combat 6 75kg", "genre": "Femmes", "etape": "1/16 finale combat 1 75kg -"}, {"epreuve": "Femmes, 1/16 finale combat 2 75kg", "genre": "Femmes", "etape": "1/16 finale combat 3 75kg -"}, {"epreuve": "Femmes, 1/16 finale combat 4 60kg", "genre": "Femmes", "etape": "1/16 finale combat 3 75kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Hommes", "etape": "1/16 finale combat 5 57kg -"}, {"epreuve": "Hommes, 1/16 finale combat 6 57kg", "genre": "Hommes", "etape": "1/16 finale combat 7 71kg -"}, {"epreuve": "Hommes, 1/16 finale combat 7 71kg", "genre": "Hommes", "etape": "1/16 finale combat 8 71kg -"}, {"epreuve": "Hommes, 1/16 finale combat 9 75kg", "genre": "Femmes", "etape": "1/16 finale combat 5 75kg -"}, {"epreuve": "Femmes, 1/16 finale combat 6 60kg", "genre": "Femmes", "etape": "quart de finale combat 16 60kg -"}, {"epreuve": "Femmes, 1/16 finale combat 6 60kg", "genre": "Femmes", "etape": "quart de finale combat 16 60kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Hommes", "etape": "1/16 finale combat 8 57kg -"}, {"epreuve": "Hommes, 1/16 finale combat 9 57kg", "genre": "Hommes", "etape": "1/16 finale combat 10 71kg -"}, {"epreuve": "Hommes, 1/16 finale combat 10 71kg", "genre": "Hommes", "etape": "1/16 finale combat 11 71kg -"}, {"epreuve": "Hommes, 1/16 finale combat 12 75kg", "genre": "Femmes", "etape": "1/16 finale combat 9 75kg -"}, {"epreuve": "Femmes, 1/16 finale combat 10 60kg", "genre": "Femmes", "etape": "1/16 finale combat 9 75kg -"}]}
# Boxe {"content": [{"epreuve": "50kg", "genre": "Femmes", "etape": "1/16 finale combat 7 50kg -"}, {"epreuve": "Femmes, 1/16 finale combat 8 50kg", "genre": "Femmes", "etape": "1/16 finale combat 9 66kg -"}, {"epreuve": "Femmes, 1/16 finale combat 5 66kg", "genre": "Femmes", "etape": "1/16 finale combat 6 66kg -"}, {"epreuve": "Femmes, 1/16 finale combat 7 54kg", "genre": "Femmes", "etape": "quart de finale combat 15 63,5kg -"}, {"epreuve": "Hommes quart de finale combat 13 92kg", "genre": "Femmes", "etape": "quart de finale combat 15 63,5kg -"}]}
# Boxe {"content": [{"epreuve": "50kg", "genre": "Femmes", "etape": "1/16 finale combat 10 50kg -"}, {"epreuve": "Femmes, 1/16 finale combat 11 50kg", "genre": "Femmes", "etape": "1/16 finale combat 12 66kg -"}, {"epreuve": "Femmes, 1/16 finale combat 8 66kg", "genre": "Femmes", "etape": "1/16 finale combat 9 66kg -"}, {"epreuve": "Femmes, 1/16 finale combat 10 54kg", "genre": "Femmes", "etape": "quart de finale combat 16 54kg -"}, {"epreuve": "Femmes, quart de finale combat 17 92kg", "genre": "Femmes", "etape": "quart de finale combat 16 54kg -"}]}
# Boxe {"content": [{"epreuve": "50kg", "genre": "Femmes", "etape": "1/16 finale combat 13 50kg -"}, {"epreuve": "Femmes, 1/16 finale combat 14 66kg", "genre": "Femmes", "etape": "1/16 finale combat 11 66kg -"}, {"epreuve": "Femmes, 1/16 finale combat 12 54kg", "genre": "Femmes", "etape": "quart de finale combat 18 63,5kg -"}, {"epreuve": "Hommes quart de finale combat 15 63,5kg", "genre": "Femmes", "etape": "quart de finale combat 18 63,5kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Femmes", "etape": "1/16 finale combat 7 57kg -"}, {"epreuve": "Femmes, 1/16 finale combat 8 57kg", "genre": "Femmes", "etape": "1/16 finale combat 9 57kg -"}, {"epreuve": "Femmes, 1/16 finale combat 10 51kg", "genre": "Hommes quart de finale combat 9 51kg - Hommes quart de finale combat 10 80kg - Hommes quart de finale combat 11 80kg - Hommes quart de finale combat 12 +92 kg- Hommes", "etape": "quart de finale combat 9 +92 kg-"}, {"epreuve": "Femmes, 1/16 finale combat 10 51kg", "genre": "Hommes quart de finale combat 9 51kg - Hommes quart de finale combat 10 80kg - Hommes quart de finale combat 11 80kg - Hommes quart de finale combat 12 +92 kg- Hommes", "etape": "quart de finale combat 9 +92 kg-"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Femmes", "etape": "1/16 finale combat 11 57kg -"}, {"epreuve": "Femmes, 1/16 finale combat 12 57kg", "genre": "Femmes", "etape": "1/16 finale combat 13 57kg -"}, {"epreuve": "Femmes, 1/16 finale combat 14 51kg", "genre": "Hommes quart de finale combat 11 51kg - Hommes quart de finale combat 12 80kg - Hommes quart de finale combat 13 80kg - Hommes quart de finale combat 14 +92 kg- Hommes", "etape": "quart de finale combat 11 +92 kg-"}, {"epreuve": "Femmes, 1/16 finale combat 14 51kg", "genre": "Hommes quart de finale combat 11 51kg - Hommes quart de finale combat 12 80kg - Hommes quart de finale combat 13 80kg - Hommes quart de finale combat 14 +92 kg- Hommes", "etape": "quart de finale combat 11 +92 kg-"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Hommes", "etape": "quart de finale, combat 11 57kg -"}, {"epreuve": "Hommes, quart de finale, combat 12 71kg", "genre": "Hommes", "etape": "quart de finale, combat 13 71kg -"}, {"epreuve": "Hommes, quart de finale, combat 14 50kg", "genre": "Femmes", "etape": "quart de finale, combat 15 50kg -"}, {"epreuve": "Femmes, quart de finale, combat 16 66kg", "genre": "femmes", "etape": "quart de finale, combat 15 50kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "Hommes", "etape": "quart de finale, combat 13 57kg -"}, {"epreuve": "Hommes, quart de finale, combat 14 71kg", "genre": "Hommes", "etape": "quart de finale, combat 15 71kg -"}, {"epreuve": "Hommes, quart de finale, combat 16 50kg", "genre": "Femmes", "etape": "quart de finale, combat 17 50kg -"}, {"epreuve": "Femmes, quart de finale, combat 18 66kg", "genre": "femmes", "etape": "quart de finale, combat 17 50kg -"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "femmes"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "femmes"}]}
# Boxe None
# Boxe {"content": [{"epreuve": "57kg", "genre": "femmes"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "hommes"}]}
# Boxe {"content": [{"epreuve": "71kg", "genre": "hommes"}]}
# Boxe {"content": [{"epreuve": "57kg", "genre": "femmes"}]}
# Canoe slalom {"content": [{"epreuve": "Cano\u00eb", "genre": "hommes", "etape": "\u00e9liminatoires - manches 1 et 2"}, {"epreuve": "Kayak", "genre": "femmes", "etape": "\u00e9liminatoires - manches 1 et 2"}]}
# Canoe slalom {"content": [{"epreuve": "Kayak", "genre": "femmes", "etape": "demi-finale"}, {"epreuve": "Kayak", "genre": "femmes", "etape": "demi-finale"}]}
# Canoe slalom {"content": [{"epreuve": "Cano\u00eb", "genre": "hommes", "etape": "demi-finale"}, {"epreuve": "Cano\u00eb", "genre": "hommes", "etape": "demi-finale"}]}
# Canoe slalom {"content": [{"epreuve": "Cano\u00eb", "genre": "femmes", "etape": "\u00e9liminatoires - manches 1 et 2"}, {"epreuve": "Kayak", "genre": "hommes", "etape": "\u00e9liminatoires - manches 1 et 2"}]}
# Canoe slalom {"content": [{"epreuve": "Cano\u00eb", "genre": "femmes", "etape": "demi-finale"}, {"epreuve": "Cano\u00eb", "genre": "femmes", "etape": "demi-finale"}]}
# Canoe slalom {"content": [{"epreuve": "Kayak", "genre": "hommes", "etape": "demi-finale"}, {"epreuve": "Kayak", "genre": "hommes", "etape": "demi-finale"}]}
# Canoe slalom {"content": [{"epreuve": "Kayak Cross", "genre": "femmes", "etape": "contre-la-montre"}, {"epreuve": "Kayak Cross", "genre": "hommes", "etape": "contre-la-montre"}, {"epreuve": "Kayak Cross", "genre": "femmes", "etape": ""}, {"epreuve": "Rep\u00eachage 1 Kayak Cross", "genre": "hommes", "etape": ""}, {"epreuve": "Rep\u00eachage 1 Kayak Cross", "genre": "femmes", "etape": ""}, {"epreuve": "Rep\u00eachage 2 Kayak Cross", "genre": "hommes", "etape": ""}, {"epreuve": "Rep\u00eachage 2 Kayak Cross", "genre": "hommes", "etape": ""}]}
# Canoe slalom {"content": [{"epreuve": "Kayak Cross", "genre": "hommes", "etape": ""}, {"epreuve": "Eliminatoires Kayak Cross", "genre": "femmes", "etape": ""}, {"epreuve": "Eliminatoires Kayak Cross", "genre": "femmes", "etape": ""}]}
# Canoe slalom {"content": [{"epreuve": "Kayak Cross", "genre": "femmes", "etape": "quarts de finale"}, {"epreuve": "Kayak Cross", "genre": "hommes", "etape": "quarts de finale"}, {"epreuve": "Kayak Cross", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Kayak Cross", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Kayak Cross", "genre": "femmes", "etape": "petite finale"}, {"epreuve": "Kayak Cross", "genre": "hommes", "etape": "petite finale"}]}
# Canoë, course en ligne {"content": [{"epreuve": "Kayak \u00e0 quatre (K4) 500 m", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Kayak \u00e0 quatre (K4) 500 m", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Kayak biplace (K2) 500 m", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Kayak biplace (K2) 500 m", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "hommes", "etape": "quarts de finale"}, {"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "femmes", "etape": "quarts de finale"}, {"epreuve": "Kayak biplace (K2) 500 m", "genre": "femmes", "etape": "quarts de finale"}, {"epreuve": "Kayak biplace (K2) 500 m", "genre": "hommes", "etape": "quarts de finale"}]}
# Canoë, course en ligne {"content": [{"epreuve": "Kayak monoplace (K1) 500 m", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Kayak monoplace (K1) 1 000 m", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Cano\u00eb monoplace (C1) 1 000 m", "genre": "hommes", "etape": "\u00e9liminatoires"}, {"epreuve": "Kayak monoplace (K1) 500m", "genre": "femmes", "etape": "quarts de finale"}, {"epreuve": "Kayak monoplace (K1) 1 000 m", "genre": "hommes", "etape": "quarts de finale"}, {"epreuve": "Cano\u00eb monoplace (C1) 1 000 m", "genre": "hommes", "etape": "quarts de finale"}]}
# Canoë, course en ligne {"content": [{"epreuve": "Cano\u00eb monoplace (C1) 200 m", "genre": "femmes", "etape": "\u00e9liminatoires"}, {"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Kayak \u00e0 quatre (K4) 500 m", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Kayak \u00e0 quatre (K4) 500 m", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Cano\u00eb monoplace (C1) 200 m", "genre": "femmes", "etape": "quarts de finale"}, {"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "hommes", "etape": "finale"}]}
# Canoë, course en ligne {"content": [{"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Kayak biplace (K2) 500 m", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Kayak biplace (K2) 500 m", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Cano\u00eb monoplace (C1) 1 000 m", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Cano\u00eb biplace (C2) 500 m", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Kayak biplace (K2) 500 m", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Kayak biplace (K2) 500 m", "genre": "hommes", "etape": "finale"}, {"epreuve": "B Cano\u00eb monoplace (C1) 1 000 m", "genre": "hommes", "etape": "finale"}]}
# Canoë, course en ligne {"content": [{"epreuve": "Kayak monoplace (K1) 500 m", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Kayak monoplace (K1) 1 000 m", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "Cano\u00eb monoplace (C1) 200 m", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "Kayak monoplace (K1) 500 m", "genre": "femmes", "etape": "finale"}, {"epreuve": "C Kayak monoplace (K1) 500 m", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Kayak monoplace (K1) 1 000 m", "genre": "hommes", "etape": "finale"}, {"epreuve": "B Cano\u00eb monoplace (C1) 200 m", "genre": "femmes", "etape": "finale"}, {"epreuve": "B Cano\u00eb monoplace (C1) 200 m", "genre": "femmes", "etape": "finale"}]}
# Cyclisme sur piste None
# Cyclisme sur piste {"content": [{"epreuve": "Poursuite par \u00e9quipes", "genre": "femmes", "etape": "qualifications"}, {"epreuve": "Vitesse par \u00e9quipes", "genre": "hommes", "etape": "1er tour"}, {"epreuve": "Poursuite par \u00e9quipes", "genre": "hommes", "etape": "1er tour"}, {"epreuve": "Vitesse par \u00e9quipes", "genre": "hommes", "etape": "1er tour"}]}
# Cyclisme sur piste {"content": [{"epreuve": "Vitesse", "genre": "hommes", "etape": "qualifications"}, {"epreuve": "Keirin", "genre": "femmes", "etape": "1er tour"}, {"epreuve": "Poursuite par \u00e9quipes", "genre": "femmes", "etape": "1er tour"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "32e finale"}, {"epreuve": "Keirin", "genre": "femmes", "etape": "rep\u00eachages"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "rep\u00eachages"}]}
# Cyclisme sur piste {"content": [{"epreuve": "Vitesse", "genre": "hommes", "etape": "16e finale"}, {"epreuve": "Poursuite par \u00e9quipes", "genre": "hommes", "etape": "finales"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "16e finale - rep\u00eachages"}, {"epreuve": "Poursuite par \u00e9quipes", "genre": "femmes", "etape": "finales"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "8e finale"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "8e finale"}]}
# Cyclisme sur piste {"content": [{"epreuve": "Omnium", "genre": "hommes", "etape": "scratch 1/4"}, {"epreuve": "Keirin", "genre": "femmes", "etape": "1/4 finale"}, {"epreuve": "Omnium", "genre": "hommes", "etape": "course tempo 2/4"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "1/4 finale"}, {"epreuve": "Keirin", "genre": "femmes", "etape": "1/2 finales"}, {"epreuve": "Omnium", "genre": "hommes", "etape": "course \u00e0 l'\u00e9limination"}, {"epreuve": "Keirin", "genre": "femmes", "etape": "finale 7-12"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "finale 7-12"}]}
# Cyclisme sur piste {"content": [{"epreuve": "Vitesse", "genre": "femmes", "etape": "qualifications"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "1/2 finales"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "32e finale"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "32e finale"}]}
# Cyclisme sur piste {"content": [{"epreuve": "Madison", "genre": "femmes", "etape": "finale"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "16e finale"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "finales"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "finales"}]}
# Cyclisme sur piste {"content": [{"epreuve": "Vitesse", "genre": "femmes", "etape": "8e finale"}, {"epreuve": "Keirin", "genre": "hommes", "etape": "1er tour"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "8e finale - rep\u00eachages"}, {"epreuve": "Madison", "genre": "hommes", "etape": "finale"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "1/4 finale"}, {"epreuve": "Keirin", "genre": "hommes", "etape": "1/4 finale"}]}
# Cyclisme sur piste {"content": [{"epreuve": "Omnium", "genre": "femmes", "etape": "scratch 1/4"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "1/2 finales"}, {"epreuve": "Keirin", "genre": "hommes", "etape": "1/4 finale"}, {"epreuve": "Omnium", "genre": "femmes", "etape": "course tempo 2/4"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "places 5-8"}, {"epreuve": "Keirin", "genre": "hommes", "etape": "1/2 finales"}, {"epreuve": "Omnium", "genre": "femmes", "etape": "course \u00e0 l'\u00e9limination"}, {"epreuve": "Keirin", "genre": "hommes", "etape": "course \u00e0 l'\u00e9limination"}]}
# Cyclisme sur route {"content": []}
# Cyclisme sur route {"content": [{"epreuve": "Course en ligne"}]}
# Cyclisme sur route {"content": [{"epreuve": "Course en ligne"}]}
# Escalade {"content": [{"epreuve": "Bloc", "genre": "hommes", "etape": "demi-finale"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "demi-finale"}]}
# Escalade {"content": [{"epreuve": "Bloc", "genre": "femmes", "etape": "demi-finale"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "demi-finale"}]}
# Escalade {"content": [{"epreuve": "Difficult\u00e9", "genre": "hommes", "etape": "demi-finale"}, {"epreuve": "Vitesse", "genre": "femmes", "etape": "demi-finale"}]}
# Escalade {"content": [{"epreuve": "Difficult\u00e9", "genre": "femmes", "etape": "demi-finale"}, {"epreuve": "Vitesse", "genre": "hommes", "etape": "demi-finale"}]}
# Escalade {"content": [{"epreuve": "Bloc & Difficult\u00e9", "genre": "hommes"}]}
# Escalade {"content": [{"epreuve": "Bloc & Difficult\u00e9", "genre": "femmes"}]}
# Escrime {"content": [{"epreuve": "\u00c9p\u00e9e individuelle", "genre": "femmes", "etape": "tableau de 64"}, {"epreuve": "Sabre individuel", "genre": "hommes", "etape": "tableau de 64"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "femmes", "etape": "tableau de 32"}, {"epreuve": "Sabre individuel", "genre": "hommes", "etape": "tableau de 32"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "femmes", "etape": "tableau de 16"}, {"epreuve": "Sabre individuel", "genre": "hommes", "etape": "tableau de 16"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "femmes", "etape": "1/4 finale"}, {"epreuve": "Sabre individuel", "genre": "hommes", "etape": "1/4 finale"}]}
# Escrime {"content": [{"epreuve": "\u00c9p\u00e9e individuelle", "genre": "femmes", "etape": "1/2 finales"}, {"epreuve": "Sabre individuel", "genre": "hommes", "etape": "1/2 finales"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "femmes", "etape": "match de bronze"}, {"epreuve": "Sabre individuel", "genre": "hommes", "etape": "match bronze"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "femmes", "etape": "match d'or"}, {"epreuve": "Sabre individuel", "genre": "hommes", "etape": "match d'or"}]}
# Escrime {"content": [{"epreuve": "Fleuret individuel", "genre": "femmes", "etape": "tableau de 64"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "hommes", "etape": "tableau de 64"}, {"epreuve": "Fleuret individuel", "genre": "femmes", "etape": "tableau de 32"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "hommes", "etape": "tableau de 32"}, {"epreuve": "Fleuret individuel", "genre": "femmes", "etape": "tableau de 16"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "hommes", "etape": "tableau de 16"}, {"epreuve": "Fleuret individuel", "genre": "femmes", "etape": "1/4 finale"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "hommes", "etape": "1/4 finale"}]}
# Escrime {"content": [{"epreuve": "Fleuret individuel", "genre": "femmes", "etape": "1/2 finales"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "hommes", "etape": "1/2 finales"}, {"epreuve": "Fleuret individuel- femmes, match bronze \u00c9p\u00e9e individuelle", "genre": "hommes", "etape": "match bronze"}, {"epreuve": "Fleuret individuel", "genre": "femmes", "etape": "match d'or"}, {"epreuve": "\u00c9p\u00e9e individuelle", "genre": "hommes", "etape": "match d'or"}]}
# Escrime {"content": [{"epreuve": "Sabre individuel", "genre": "femmes", "etape": "tableau de 64"}, {"epreuve": "Fleuret individuel", "genre": "hommes", "etape": "tableau de 64"}, {"epreuve": "Sabre individuel", "genre": "femmes", "etape": "tableau de 32"}, {"epreuve": "Fleuret individuel", "genre": "hommes", "etape": "tableau de 32"}, {"epreuve": "Sabre individuel", "genre": "femmes", "etape": "tableau de 16"}, {"epreuve": "Fleuret individuel", "genre": "hommes", "etape": "tableau de 16"}, {"epreuve": "Sabre individuel", "genre": "femmes", "etape": "1/4 finale"}, {"epreuve": "Fleuret individuel", "genre": "hommes", "etape": "1/4 finale"}]}
# Escrime {"content": [{"epreuve": "Sabre individuel", "genre": "femmes", "etape": "1/2 finales"}, {"epreuve": "Fleuret individuel", "genre": "hommes", "etape": "1/2 finales"}, {"epreuve": "Sabre individuel", "genre": "femmes", "etape": "match bronze"}, {"epreuve": "Fleuret individuel", "genre": "hommes", "etape": "match bronze"}]}
# ...
# Tir a l'arc {"content": [{"epreuve": "\u00c9preuve individuelle", "genre": "hommes", "etape": "\u00e9liminatoires (32e de finale)"}, {"epreuve": "\u00c9preuve individuelle", "genre": "femmes", "etape": "\u00e9liminatoires (32e de finale)"}, {"epreuve": "\u00c9preuve individuelle", "genre": "hommes", "etape": "\u00e9liminatoires (16e de finale)"}, {"epreuve": "\u00c9preuve individuelle", "genre": "femmes", "etape": "\u00e9liminatoires (16e de finale)"}]}
# Tir a l'arc {"content": [{}]}
# Tir a l'arc {"content": [{}]}
# Tir a l'arc {"content": [{"epreuve": "\u00c9preuve individuelle", "genre": "femmes"}]}
# Tir a l'arc {"content": [{"epreuve": "\u00c9preuve individuelle", "genre": "femmes", "etape": "quarts de finale"}, {"epreuve": "\u00c9preuve individuelle", "genre": "femmes", "etape": "demi-finales"}, {"epreuve": "\u00c9preuve individuelle", "genre": "femmes", "etape": "match pour la m\u00e9daille de bronze"}, {"epreuve": "\u00c9preuve individuelle", "genre": "femmes", "etape": "match pour la m\u00e9daille de bronze"}]}
# Tir a l'arc {"content": [{"epreuve": "\u00c9preuve individuelle", "genre": "hommes"}]}
# Tir a l'arc {"content": [{"epreuve": "\u00c9preuve individuelle", "genre": "hommes", "etape": "quarts de finale"}, {"epreuve": "\u00c9preuve individuelle", "genre": "hommes", "etape": "demi-finales"}, {"epreuve": "\u00c9preuve individuelle", "genre": "hommes", "etape": "match pour la m\u00e9daille de bronze"}, {"epreuve": "\u00c9preuve individuelle", "genre": "hommes", "etape": "match pour la m\u00e9daille de bronze"}]}
# Tir {"content": [{"epreuve": "Carabine \u00e0 air comprim\u00e9 10 m", "genre": "\u00e9quipe mixte"}]}
# Tir {"content": []}
# Tir {"content": [{"epreuve": "10 m rifle \u00e0 air", "genre": "femmes"}]}
# Tir {"content": []}
# Tir {"content": [{"epreuve": "Pistolet \u00e0 air comprim\u00e9 10 m", "genre": "\u00e9quipe mixte", "etape": "qualification"}, {"epreuve": "D\u00e9but : 09:00 Fin : 16:00 Centre National de Tir de Ch\u00e2teauroux* Nom de l'\u00e9preuve/des \u00e9preuves Fosse olympique", "genre": "hommes", "etape": "qualification"}]}
# Tir {"content": [{"epreuve": "Fosse olympique", "genre": "hommes"}]}
# Tir {"content": []}
# Tir {"content": [{"epreuve": "50 m rifle 3 positions", "genre": "hommes"}]}
# Tir {"content": [{"epreuve": "Fosse olympique", "genre": "femmes"}]}
# Tir {"content": []}
# Tir {"content": [{"epreuve": "50 m rifle 3 positions", "genre": "femmes"}]}
# Tir {"content": [{"epreuve": "Skeet", "genre": "hommes"}]}
# Tir {"content": [{"epreuve": "25 m pistolet", "genre": "femmes", "etape": "qualification"}, {"epreuve": "D\u00e9but : 09:30 Fin : 10:50 Centre National de Tir de Ch\u00e2teauroux* Nom de l'\u00e9preuve/des \u00e9preuves 50 m rifle 3 positions", "genre": "femmes", "etape": "qualification"}]}
# Tir {"content": [{"epreuve": "Skeet", "genre": "hommes"}]}
# Tir {"content": []}
# Tir {"content": [{"epreuve": "25 m pistolet feu rapide", "genre": "hommes"}]}
# Tir {"content": [{"epreuve": "Skeet", "genre": "femmes"}]}
# Tir {"content": [{"epreuve": "Skeet", "genre": "\u00e9quipe mixte"}]}
# Tir {"content": []}
# Triathlon None
# Triathlon None
# Triathlon None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Voile None
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Tour pr\u00e9liminaire", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Tour pr\u00e9liminaire", "genre": ""}, {"etape": "Femmes et hommes (2 matchs) Lucky Loser", "genre": ""}, {"etape": "Femmes et hommes (2 matchs) Lucky Loser", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Lucky Losers", "genre": ""}, {"etape": "Lucky Losers", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "8e de finale", "genre": ""}, {"etape": "8e de finale", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Quarts de finales", "genre": ""}, {"etape": "Quarts de finales", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Quarts de finales", "genre": ""}, {"etape": "Quarts de finales", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Quarts de finales", "genre": ""}, {"etape": "Quarts de finales", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Quarts de finales", "genre": ""}, {"etape": "Quarts de finales", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Demi-finales", "genre": ""}, {"etape": "Demi-finales", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Demi-finales", "genre": ""}, {"etape": "Demi-finales", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Match pour la m\u00e9daille de bronze", "genre": ""}, {"etape": "Femmes Match pour la m\u00e9daille d'or", "genre": ""}, {"etape": "Femmes Match pour la m\u00e9daille d'or", "genre": ""}]}
# Beach volleyball {"content": [{"etape": "Match pour la m\u00e9daille de bronze", "genre": ""}, {"etape": "Hommes Match pour la m\u00e9daille d'or", "genre": ""}, {"etape": "Hommes Match pour la m\u00e9daille d'or", "genre": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Hommes", "etape": ""}, {"genre": "Hommes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Volleyball {"content": [{"genre": "Femmes", "etape": ""}, {"genre": "Femmes", "etape": ""}]}
# Vtt None
# Vtt None
# Water polo None
# Water polo None
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Femmes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Hommes"}]}
# Water polo {"content": [{"genre": "Femmes", "etape": "match de classement"}, {"genre": "Femmes", "etape": "match de classement"}]}
# Water polo {"content": [{"genre": "Femmes", "etape": "match de classement"}, {"genre": "Femmes", "etape": "match de classement"}]}
# Water polo {"content": [{"genre": "Hommes", "etape": "match de classement"}, {"genre": "Hommes", "etape": "match de classement"}]}
# Water polo {"content": [{"genre": "Hommes", "etape": "match de classement"}, {"genre": "Hommes", "etape": "match de classement"}]}
# Water polo {"content": [{"genre": "Femmes", "etape": "match de classement"}, {"genre": "Femmes", "etape": "match de classement"}]}
# Water polo {"content": [{"genre": "Femmes", "etape": "match de classement"}, {"genre": "Femmes", "etape": "match pour la m\u00e9daille d'or"}, {"genre": "Hommes", "etape": "match pour la m\u00e9daille d'or"}]}
# Water polo {"content": [{"genre": "Hommes", "etape": "match de classement"}, {"genre": "Hommes", "etape": "match de classement"}]}
# Water polo {"content": [{"genre": "Hommes"}]}

# %%
n = 150
print(df['discipline'][n], '  ', df['parsing_epreuve'][n])
# Out:
# CANOE SLALOM    [{'epreuve': 'Canoë', 'genre': 'hommes', 'etape': 'demi-finale'}, {'epreuve': 'Canoë', 'genre': 'hommes', 'etape': 'demi-finale'}]

# %%
disc = str(df['num_session'][731])[:3]
cle_parser = match_cle_parser(disc, cles_parsers)
print(cle_parser)
print(parser(df['nom_epreuve'][731], cle_parser['separateurs'], cle_parser['noms']))
print('gh')

df['nom_epreuve'][731]
# Out:
# {'separateurs': [', '], 'noms': ['genre', 'etape']}
# [{'genre': 'Femmes', 'etape': 'match de classement'}, {'genre': 'Femmes', 'etape': 'match de classement'}]
# gh
# {'separateurs': [', '], 'noms': ['genre', 'etape']}
# 'Femmes, match de classement Femmes, match pour la médaille de bronze'

# %%
cle_parser('BKB', cles_parsers)
# Out:
# {'separateurs': [', '], 'noms': ['genre', 'etape']}

# %%
cles_parsers = {'A' : {'hj' : 'gh', 'é' : 'hio'}}

# %%
cles_parsers = {
    'A' : [[' - ', ', '], ['epreuve', 'genre', 'etape']], 
    'B' : {
        'separateurs' : [', '],
        'noms' : ['genre', 'etape']
    }
}

# %%
df['discipline'].unique()
# Out:
# array(['ATHLETISME', 'AVIRON', 'BADMINTON', 'BASKETBALL',
#        'BASKETBALL 3x3', 'BMX FREESTYLE', 'BMX RACING', 'Breaking',
#        'BOXE', 'CANOE SLALOM', 'CANOË, COURSE EN LIGNE',
#        'CYCLISME SUR PISTE', 'CYCLISME SUR ROUTE', 'Escalade', 'ESCRIME',
#        'FOOTBALL', 'GOLF', 'GYMNASTIQUE ARTISTIQUE',
#        'GYMNASTIQUE TRAMPOLINE', 'Gymnastique rythmique', 'HALTEROPHILIE',
#        'HANDBALL', 'HOCKEY', 'JUDO', 'LUTTE', 'Natation',
#        'NATATION ARTISTIQUE', 'NATATION MARATHON', 'Pentathlon Moderne',
#        'PLONGEON', 'RUGBY', 'SPORTS EQUESTRES', 'SURFING', 'TAEKWONDO',
#        'TENNIS', 'TENNIS DE TABLE', "TIR A L'ARC", 'TIR', 'TRIATHLON',
#        'VOILE', 'BEACH VOLLEYBALL', 'VOLLEYBALL', 'VTT', 'WATER POLO'],
#       dtype=object)

# %%
for row in df:
    print(row)

#df['num_session']
# Out:
# num_jour
# date
# discipline
# num_session
# debut_epreuve
# fin_epreuve
# lieu_epreuve
# nom_epreuve

# %%
etapes_mots = ['demi-finales A/B', 'qualifications', 'repêchage']
genre_mots = ['hommes', 'femmes', 'finale B']

def parser1(texte):
    liste_epreuves = []
    epreuve, genre, etape = '', '', ''
    i, i0 = 0, 0
    while i < len(texte):
        while i < len(texte):
            if i + 4 < len(texte) and texte[i:i+3] == ' - ':
                epreuve = texte[i0:i]
                i+=3
                i1 = i
                break
            i+=1

        while i < len(texte):
            if i + 3 < len(texte) and texte[i:i+2] == ', ':
                genre = texte[i1:i]
                i+=2
                i2 = i
                break
            i+=1

        while i < len(texte):
            if texte[i].isupper():
                etape = texte[i2:i-1]
                i0 = i
                break
            i+=1
        liste_epreuves.append({"epreuve" : epreuve, "genre" : genre, "etape" : etape})
        i+=1
    return liste_epreuves 
        
    #texte.split(' - ')
    #epreuve, genre, etape =

# %%
separateurs = [' - ', ', ']
noms = ['epreuve', 'genre', 'etape']

parser2(df['nom_epreuve'][25], separateurs, noms)
# Out:
# [{'epreuve': 'Skiff', 'genre': 'femmes', 'etape': 'demi-finales'},
#  {'epreuve': 'A/B Skiff', 'genre': 'hommes', 'etape': 'demi-finales'},
#  {'epreuve': 'A/B Huit de pointe avec barreur',
#   'genre': 'femmes',
#   'etape': 'repêchage'},
#  {'epreuve': 'Huit de pointe avec barreur',
#   'genre': 'hommes',
#   'etape': 'repêchage'},
#  {'epreuve': 'Deux de couple', 'genre': 'femmes', 'etape': 'finale'},
#  {'epreuve': 'B Deux de couple', 'genre': 'hommes', 'etape': 'finale'},
#  {'epreuve': 'B Quatre de pointe sans barreur',
#   'genre': 'femmes',
#   'etape': 'finale'},
#  {'epreuve': 'B Quatre de pointe sans barreur',
#   'genre': 'hommes',
#   'etape': 'finale'}]

# %%
t = 'hjk'
t[1:2]
# Out:
# 'j'

# %%
def parser2(texte):

# %%
parser1(df['nom_epreuve'][25])
# Out:
# [{'epreuve': 'Skiff', 'genre': 'femmes', 'etape': 'demi-finales'},
#  {'epreuve': 'A/B Skiff', 'genre': 'hommes', 'etape': 'demi-finales'},
#  {'epreuve': 'A/B Huit de pointe avec barreur',
#   'genre': 'femmes',
#   'etape': 'repêchage'},
#  {'epreuve': 'Huit de pointe avec barreur',
#   'genre': 'hommes',
#   'etape': 'repêchage'},
#  {'epreuve': 'Deux de couple', 'genre': 'femmes', 'etape': 'finale'},
#  {'epreuve': 'B Deux de couple', 'genre': 'hommes', 'etape': 'finale'},
#  {'epreuve': 'B Quatre de pointe sans barreur',
#   'genre': 'femmes',
#   'etape': 'finale'},
#  {'epreuve': 'B Quatre de pointe sans barreur',
#   'genre': 'hommes',
#   'etape': 'finale'}]

# %%
df['nom_epreuve'][25]
# Out:
# 'Skiff - femmes, demi-finales A/B Skiff - hommes, demi-finales A/B Huit de pointe avec barreur - femmes, repêchage Huit de pointe avec barreur - hommes, repêchage Deux de couple - femmes, finale B Deux de couple - hommes, finale B Quatre de pointe sans barreur - femmes, finale B Quatre de pointe sans barreur - hommes, finale B'
